# %% [markdown]
# * Create a heat map that displays the humidity for every city from the part I of the homework.
#
# * Narrow down the DataFrame to find your ideal weather condition. For example:
#
#   * A max temperature lower than 80 degrees but higher than 70.
#
#   * Wind speed less than 10 mph.
#
#   * Zero cloudiness.
#
#   * Drop any rows that don't contain all three conditions. You want to be sure the weather is ideal.
#
#   * **Note:** Feel free to adjust to your specifications but be sure to limit the number of rows returned by your API requests to a reasonable number.
#
# * Using Google Places API to find the first hotel for each city located within 5000 meters of your coordinates.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import json

# Import API key
from api_keys import g_key
# g_key

# %%
#load the csv from Part 1 into a dataframe
weather_data_df = pd.read_csv("../WeatherPy/output_data/weatherPy_clean_data.csv") 
weather_data_df.head()
# Out:
#              City Country    Lat     Lon  Max Temp  Humidity        Date  \
# 0      coahuayana      MX  18.73 -103.68     71.60        78  1595251434
# 1          dingle      PH  11.00  122.67     78.69        80  1595251435
# 2  ribeira grande      PT  38.52  -28.70     73.40        60  1595251420
# 3         botwood      CA  49.15  -55.35     75.20        50  1595251437
# 4            hilo      US  19.73 -155.09     75.20        78  1595251142
#
#    Clouds  Wind Speed
# 0       5        9.17
# 1      11        5.26
# 2      75        6.93
# 3      20        6.93
# 4      90        5.82

# %%
gmaps.configure(api_key=g_key)

# %%
#configre gmaps, use lat/lng as locations and humidity as weight, add heatmap layer to map

locations = weather_data_df[["Lat", "Lon"]]
weights = weather_data_df["Humidity"]

fig = gmaps.figure()

heat_map = gmaps.heatmap_layer(locations, weights, dissipating=False, max_intensity=100, point_radius = 1)

fig.add_layer(heat_map)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#create new dataframe to fit weather criteria, do the loc, drop null values


myIdeal = ((weather_data_df['Max Temp'] >= 60) & (weather_data_df['Max Temp'] <=75) & (weather_data_df['Clouds'] <40) & 
    (weather_data_df['Humidity'] <=80)) 
myIdeal.value_counts()
# Out:
# False    482
# True      51
# dtype: int64

# %%
perfect_vaca = weather_data_df.loc[myIdeal, :]

drop_ideal = perfect_vaca.dropna(how="any")
drop_ideal.count()

drop_ideal
# Out:
#                   City Country    Lat     Lon  Max Temp  Humidity        Date  \
# 0           coahuayana      MX  18.73 -103.68     71.60        78  1595251434
# 20         port alfred      ZA -33.59   26.89     71.58        33  1595251158
# 24   sao mateus do sul      BR -25.87  -50.38     65.61        62  1595251464
# 27        kruisfontein      ZA -34.00   24.73     68.67        49  1595251063
# 33            maniwaki      CA  46.38  -75.97     71.89        63  1595251477
# 37      saint-philippe      RE -21.36   55.77     71.60        60  1595251205
# 40              beloha      MG -25.17   45.05     71.29        51  1595251487
# 60            lamballe      FR  48.47   -2.51     70.00        62  1595251514
# 62      port elizabeth      ZA -33.92   25.57     66.20        72  1595250928
# 76                 voh      NC -20.97  164.70     61.25        73  1595251535
# 86        ponta do sol      PT  32.67  -17.10     75.00        61  1595250932
# 91            hermanus      ZA -34.42   19.23     64.00        69  1595251130
# 95           cape town      ZA -33.93   18.42     71.01        52  1595251562
# 99        port hedland      AU -20.32  118.57     66.20        39  1595251489
# 113           cidreira      BR -30.18  -50.21     68.99        73  1595251256
# 143           haicheng      CN  40.85  122.75     67.93        69  1595251627
# 145    verkhnyaya inta      RU  65.98   60.31     73.29        38  1595251630
# 148             castro      BR -24.79  -50.01     65.19        57  1595251077
# 161            northam      GB  51.03   -4.22     66.99        57  1595251651
# 187          shelburne      CA  44.08  -80.20     73.40        69  1595251470
# 222          capiibary      PY -24.80  -56.03     71.15        57  1595251733
# 269             nongan      CN  44.38  125.17     68.00        77  1595251799
# 282             surgut      RU  61.25   73.42     66.20        52  1595251818
# 285         ridgecrest      US  35.62 -117.67     72.00        35  1595251772
# 286              lagoa      PT  39.05  -27.98     68.72        70  1595251823
# 294             cheney      US  47.49 -117.58     66.20        55  1595251834
# 297           znamenka      RU  52.42   41.43     74.64        53  1595251838
# 305        tupaciguara      BR -18.59  -48.70     66.20        55  1595251848
# 307        san quintin      MX  30.48 -115.95     69.51        73  1595251851
# 317           saldanha      ZA -33.01   17.94     73.40        53  1595251863
# 324     guerrero negro      MX  27.98 -114.06     69.40        77  1595251874
# 336             ghanzi      BW -21.57   21.78     74.12        19  1595251593
# 345          kununurra      AU -15.77  128.73     66.20        32  1595251902
# 359             mungwi      ZM -10.17   31.37     74.53        33  1595251920
# 373       suciu de sus      RO  47.43   24.03     72.00        68  1595251970
# 374           karratha      AU -20.74  116.85     70.02        47  1595251972
# 392              werda      BW -25.27   23.28     74.79        18  1595251996
# 396          kyshtovka      RU  56.55   76.63     65.62        75  1595252002
# 398      saint anthony      US  45.02  -93.22     69.80        77  1595251454
# 412               poum      NC -20.23  164.02     70.30        65  1595251269
# 414           ust-nera      RU  64.57  143.20     62.01        55  1595252027
# 435                vao      NC -22.67  167.48     68.67        73  1595252053
# 443        ferme-neuve      CA  46.70  -75.45     73.00        59  1595252063
# 449          roebourne      AU -20.78  117.13     70.00        48  1595252071
# 481          biskamzha      RU  53.45   89.53     64.06        73  1595252117
# 482         den helder      NL  52.96    4.76     64.99        59  1595252118
# 499           streator      US  41.12  -88.84     73.99        78  1595252045
# 509             babati      TZ  -4.22   35.75     74.71        38  1595252154
# 512        orange cove      US  36.62 -119.31     69.01        72  1595252158
# 521   valle de allende      MX  26.93 -105.40     71.56        54  1595252173
#
#      Clouds  Wind Speed
# 0         5        9.17
# 20        0        8.30
# 24        0        3.22
# 27        0        8.21
# 33        0       10.33
# 37       20       24.16
# 40        0       16.11
# 60        2        8.01
# 62       20       13.87
# 76        0        3.00
# 86        0        1.36
# 91        0        4.00
# 95        0        6.93
# 99        0        9.17
# 113       0        2.93
# 143       0        5.14
# 145       0        5.30
# 148       0        6.85
# 161       0        3.00
# 187       1       10.29
# 222       0        8.95
# 269       0        6.71
# 282      32       11.18
# 285      20        4.70
# 286      13        0.94
# 294      20        3.36
# 297      30        8.99
# 305       0       12.75
# 307       0       13.18
# 317       0        3.36
# 324       0        4.03
# 336       0       12.30
# 345      15        5.57
# 359      30        6.85
# 373      20        5.82
# 374       0       14.12
# 392       0        8.43
# 396       7       11.54
# 398       1        3.89
# 412      26       16.93
# 414      21        4.90
# 435       2       14.72
# 443       4       12.33
# 449       0       15.32
# 481       0        0.11
# 482       0       10.29
# 499       1        5.82
# 509       5        9.31
# 512       1        1.90
# 521       0        6.02

# %%
drop_ideal
# Out:
#                   City Country    Lat     Lon  Max Temp  Humidity        Date  \
# 0           coahuayana      MX  18.73 -103.68     71.60        78  1595251434
# 20         port alfred      ZA -33.59   26.89     71.58        33  1595251158
# 24   sao mateus do sul      BR -25.87  -50.38     65.61        62  1595251464
# 27        kruisfontein      ZA -34.00   24.73     68.67        49  1595251063
# 33            maniwaki      CA  46.38  -75.97     71.89        63  1595251477
# 37      saint-philippe      RE -21.36   55.77     71.60        60  1595251205
# 40              beloha      MG -25.17   45.05     71.29        51  1595251487
# 60            lamballe      FR  48.47   -2.51     70.00        62  1595251514
# 62      port elizabeth      ZA -33.92   25.57     66.20        72  1595250928
# 76                 voh      NC -20.97  164.70     61.25        73  1595251535
# 86        ponta do sol      PT  32.67  -17.10     75.00        61  1595250932
# 91            hermanus      ZA -34.42   19.23     64.00        69  1595251130
# 95           cape town      ZA -33.93   18.42     71.01        52  1595251562
# 99        port hedland      AU -20.32  118.57     66.20        39  1595251489
# 113           cidreira      BR -30.18  -50.21     68.99        73  1595251256
# 143           haicheng      CN  40.85  122.75     67.93        69  1595251627
# 145    verkhnyaya inta      RU  65.98   60.31     73.29        38  1595251630
# 148             castro      BR -24.79  -50.01     65.19        57  1595251077
# 161            northam      GB  51.03   -4.22     66.99        57  1595251651
# 187          shelburne      CA  44.08  -80.20     73.40        69  1595251470
# 222          capiibary      PY -24.80  -56.03     71.15        57  1595251733
# 269             nongan      CN  44.38  125.17     68.00        77  1595251799
# 282             surgut      RU  61.25   73.42     66.20        52  1595251818
# 285         ridgecrest      US  35.62 -117.67     72.00        35  1595251772
# 286              lagoa      PT  39.05  -27.98     68.72        70  1595251823
# 294             cheney      US  47.49 -117.58     66.20        55  1595251834
# 297           znamenka      RU  52.42   41.43     74.64        53  1595251838
# 305        tupaciguara      BR -18.59  -48.70     66.20        55  1595251848
# 307        san quintin      MX  30.48 -115.95     69.51        73  1595251851
# 317           saldanha      ZA -33.01   17.94     73.40        53  1595251863
# 324     guerrero negro      MX  27.98 -114.06     69.40        77  1595251874
# 336             ghanzi      BW -21.57   21.78     74.12        19  1595251593
# 345          kununurra      AU -15.77  128.73     66.20        32  1595251902
# 359             mungwi      ZM -10.17   31.37     74.53        33  1595251920
# 373       suciu de sus      RO  47.43   24.03     72.00        68  1595251970
# 374           karratha      AU -20.74  116.85     70.02        47  1595251972
# 392              werda      BW -25.27   23.28     74.79        18  1595251996
# 396          kyshtovka      RU  56.55   76.63     65.62        75  1595252002
# 398      saint anthony      US  45.02  -93.22     69.80        77  1595251454
# 412               poum      NC -20.23  164.02     70.30        65  1595251269
# 414           ust-nera      RU  64.57  143.20     62.01        55  1595252027
# 435                vao      NC -22.67  167.48     68.67        73  1595252053
# 443        ferme-neuve      CA  46.70  -75.45     73.00        59  1595252063
# 449          roebourne      AU -20.78  117.13     70.00        48  1595252071
# 481          biskamzha      RU  53.45   89.53     64.06        73  1595252117
# 482         den helder      NL  52.96    4.76     64.99        59  1595252118
# 499           streator      US  41.12  -88.84     73.99        78  1595252045
# 509             babati      TZ  -4.22   35.75     74.71        38  1595252154
# 512        orange cove      US  36.62 -119.31     69.01        72  1595252158
# 521   valle de allende      MX  26.93 -105.40     71.56        54  1595252173
#
#      Clouds  Wind Speed Hotel
# 0         5        9.17
# 20        0        8.30
# 24        0        3.22
# 27        0        8.21
# 33        0       10.33
# 37       20       24.16
# 40        0       16.11
# 60        2        8.01
# 62       20       13.87
# 76        0        3.00
# 86        0        1.36
# 91        0        4.00
# 95        0        6.93
# 99        0        9.17
# 113       0        2.93
# 143       0        5.14
# 145       0        5.30
# 148       0        6.85
# 161       0        3.00
# 187       1       10.29
# 222       0        8.95
# 269       0        6.71
# 282      32       11.18
# 285      20        4.70
# 286      13        0.94
# 294      20        3.36
# 297      30        8.99
# 305       0       12.75
# 307       0       13.18
# 317       0        3.36
# 324       0        4.03
# 336       0       12.30
# 345      15        5.57
# 359      30        6.85
# 373      20        5.82
# 374       0       14.12
# 392       0        8.43
# 396       7       11.54
# 398       1        3.89
# 412      26       16.93
# 414      21        4.90
# 435       2       14.72
# 443       4       12.33
# 449       0       15.32
# 481       0        0.11
# 482       0       10.29
# 499       1        5.82
# 509       5        9.31
# 512       1        1.90
# 521       0        6.02

# %%
#create hotel map, 5000 meters, use Places to find hotel, mark plots on heatmap, if there are more than 4-5 cities for loop

base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# target_coords = "-22.67, 167.48"
# target_type = "hotel"
# target_radius = 5000

params = {
    "location": ["Lat","Lon"],
    "rankby": "distance",
    "radius": 5000,
    "type": "hotel",
    "key": g_key
}

for index, row in drop_ideal.iterrows():
    
    hotel_type = row["City"]
    params["keyword"] = hotel_type
    
    print(f"Retrieving Results From Index {index}: {hotel_type}.")
    response = requests.get(base_url, params=params).json()
    
    results = response["results"]
    
    try:
        print(f"Closest{hotel_type} hotel is {results[1]['name']}.")
        
        drop_ideal.loc[index, "name"] = results[1]["name"]
        drop_ideal.loc[index, "vicinity"] = results[1]["vicinity"]
        drop_ideal.loc[index, "rating"] = results[1]["rating"]
    except (KeyError, IndexError):
        print("Missing information...skipping")
        print("----------------")

#     hotel_places = response.json()

# counter = 0

# for place in hotel_places["results"]:
#     print(f"The name of the hote is: {place['name']}")
#     print(f"The hotel is near {place['vicinity']}")
# #     print(place['rating'])
#     counter += 1
#     if counter == 5:
#         break
# Out:
# Retrieving Results From Index 0: coahuayana.
# Missing information...skipping
# ----------------
# Retrieving Results From Index 20: port alfred.
# Missing information...skipping
# ----------------
# Retrieving Results From Index 24: sao mateus do sul.
# Missing information...skipping
# ----------------
# Retrieving Results From Index 27: kruisfontein.
# Missing information...skipping
# ----------------
# Retrieving Results From Index 33: maniwaki.
# Missing information...skipping
# ----------------
# Retrieving Results From Index 37: saint-philippe.
# Missing information...skipping
# ----------------
# Retrieving Results From Index 40: beloha.
# Missing information...skipping
# ----------------
# Retrieving Results From Index 60: lamballe.
# Missing information...skipping
# ----------------
# Retrieving Results From Index 62: port elizabeth.
# Missing information...skipping
# ----------------
# Retrieving Results From Index 76: voh.
# Missing information...skipping
# ----------------
# Retrieving Results From Index 86: ponta do sol.
# Missing information...skipping
# ----------------
# Retrieving Results From Index 91: hermanus.
# Missing information...skipping
# ----------------
# Retrieving Results From Index 95: cape town.
# Missing information...skipping
# ----------------
# Retrieving Results From Index 99: port hedland.
# Missing information...skipping
# ----------------
# Retrieving Results From Index 113: cidreira.
# Missing information...skipping
# ----------------
# Retrieving Results From Index 143: haicheng.
# Missing information...skipping
# ----------------
# Retrieving Results From Index 145: verkhnyaya inta.
# Missing information...skipping
# ----------------
# Retrieving Results From Index 148: castro.
# Missing information...skipping
# ----------------
# Retrieving Results From Index 161: northam.
# Missing information...skipping
# ----------------
# Retrieving Results From Index 187: shelburne.
# Missing information...skipping
# ----------------
# Retrieving Results From Index 222: capiibary.
# Missing information...skipping
# ----------------
# Retrieving Results From Index 269: nongan.
# Missing information...skipping
# ----------------
# Retrieving Results From Index 282: surgut.
# Missing information...skipping
# ----------------
# Retrieving Results From Index 285: ridgecrest.
# Missing information...skipping
# ----------------
# Retrieving Results From Index 286: lagoa.
# Missing information...skipping
# ----------------
# Retrieving Results From Index 294: cheney.
# Missing information...skipping
# ----------------
# Retrieving Results From Index 297: znamenka.
# Missing information...skipping
# ----------------
# Retrieving Results From Index 305: tupaciguara.
# Missing information...skipping
# ----------------
# Retrieving Results From Index 307: san quintin.
# Missing information...skipping
# ----------------
# Retrieving Results From Index 317: saldanha.
# Missing information...skipping
# ----------------
# Retrieving Results From Index 324: guerrero negro.
# Missing information...skipping
# ----------------
# Retrieving Results From Index 336: ghanzi.
# Missing information...skipping
# ----------------
# Retrieving Results From Index 345: kununurra.
# Missing information...skipping
# ----------------
# Retrieving Results From Index 359: mungwi.
# Missing information...skipping
# ----------------
# Retrieving Results From Index 373: suciu de sus.
# Missing information...skipping
# ----------------
# Retrieving Results From Index 374: karratha.
# Missing information...skipping
# ----------------
# Retrieving Results From Index 392: werda.
# Missing information...skipping
# ----------------
# Retrieving Results From Index 396: kyshtovka.
# Missing information...skipping
# ----------------
# Retrieving Results From Index 398: saint anthony.
# Missing information...skipping
# ----------------
# Retrieving Results From Index 412: poum.
# Missing information...skipping
# ----------------
# Retrieving Results From Index 414: ust-nera.
# Missing information...skipping
# ----------------
# Retrieving Results From Index 435: vao.
# Missing information...skipping
# ----------------
# Retrieving Results From Index 443: ferme-neuve.
# Missing information...skipping
# ----------------
# Retrieving Results From Index 449: roebourne.
# Missing information...skipping
# ----------------
# Retrieving Results From Index 481: biskamzha.
# Missing information...skipping
# ----------------
# Retrieving Results From Index 482: den helder.
# Missing information...skipping
# ----------------
# Retrieving Results From Index 499: streator.
# Missing information...skipping
# ----------------
# Retrieving Results From Index 509: babati.
# Missing information...skipping
# ----------------
# Retrieving Results From Index 512: orange cove.
# Missing information...skipping
# ----------------
# Retrieving Results From Index 521: valle de allende.
# Missing information...skipping
# ----------------

# %%
drop_ideal
# Out:
#                   City Country    Lat     Lon  Max Temp  Humidity        Date  \
# 0           coahuayana      MX  18.73 -103.68     71.60        78  1595251434
# 20         port alfred      ZA -33.59   26.89     71.58        33  1595251158
# 24   sao mateus do sul      BR -25.87  -50.38     65.61        62  1595251464
# 27        kruisfontein      ZA -34.00   24.73     68.67        49  1595251063
# 33            maniwaki      CA  46.38  -75.97     71.89        63  1595251477
# 37      saint-philippe      RE -21.36   55.77     71.60        60  1595251205
# 40              beloha      MG -25.17   45.05     71.29        51  1595251487
# 60            lamballe      FR  48.47   -2.51     70.00        62  1595251514
# 62      port elizabeth      ZA -33.92   25.57     66.20        72  1595250928
# 76                 voh      NC -20.97  164.70     61.25        73  1595251535
# 86        ponta do sol      PT  32.67  -17.10     75.00        61  1595250932
# 91            hermanus      ZA -34.42   19.23     64.00        69  1595251130
# 95           cape town      ZA -33.93   18.42     71.01        52  1595251562
# 99        port hedland      AU -20.32  118.57     66.20        39  1595251489
# 113           cidreira      BR -30.18  -50.21     68.99        73  1595251256
# 143           haicheng      CN  40.85  122.75     67.93        69  1595251627
# 145    verkhnyaya inta      RU  65.98   60.31     73.29        38  1595251630
# 148             castro      BR -24.79  -50.01     65.19        57  1595251077
# 161            northam      GB  51.03   -4.22     66.99        57  1595251651
# 187          shelburne      CA  44.08  -80.20     73.40        69  1595251470
# 222          capiibary      PY -24.80  -56.03     71.15        57  1595251733
# 269             nongan      CN  44.38  125.17     68.00        77  1595251799
# 282             surgut      RU  61.25   73.42     66.20        52  1595251818
# 285         ridgecrest      US  35.62 -117.67     72.00        35  1595251772
# 286              lagoa      PT  39.05  -27.98     68.72        70  1595251823
# 294             cheney      US  47.49 -117.58     66.20        55  1595251834
# 297           znamenka      RU  52.42   41.43     74.64        53  1595251838
# 305        tupaciguara      BR -18.59  -48.70     66.20        55  1595251848
# 307        san quintin      MX  30.48 -115.95     69.51        73  1595251851
# 317           saldanha      ZA -33.01   17.94     73.40        53  1595251863
# 324     guerrero negro      MX  27.98 -114.06     69.40        77  1595251874
# 336             ghanzi      BW -21.57   21.78     74.12        19  1595251593
# 345          kununurra      AU -15.77  128.73     66.20        32  1595251902
# 359             mungwi      ZM -10.17   31.37     74.53        33  1595251920
# 373       suciu de sus      RO  47.43   24.03     72.00        68  1595251970
# 374           karratha      AU -20.74  116.85     70.02        47  1595251972
# 392              werda      BW -25.27   23.28     74.79        18  1595251996
# 396          kyshtovka      RU  56.55   76.63     65.62        75  1595252002
# 398      saint anthony      US  45.02  -93.22     69.80        77  1595251454
# 412               poum      NC -20.23  164.02     70.30        65  1595251269
# 414           ust-nera      RU  64.57  143.20     62.01        55  1595252027
# 435                vao      NC -22.67  167.48     68.67        73  1595252053
# 443        ferme-neuve      CA  46.70  -75.45     73.00        59  1595252063
# 449          roebourne      AU -20.78  117.13     70.00        48  1595252071
# 481          biskamzha      RU  53.45   89.53     64.06        73  1595252117
# 482         den helder      NL  52.96    4.76     64.99        59  1595252118
# 499           streator      US  41.12  -88.84     73.99        78  1595252045
# 509             babati      TZ  -4.22   35.75     74.71        38  1595252154
# 512        orange cove      US  36.62 -119.31     69.01        72  1595252158
# 521   valle de allende      MX  26.93 -105.40     71.56        54  1595252173
#
#      Clouds  Wind Speed Hotel
# 0         5        9.17
# 20        0        8.30
# 24        0        3.22
# 27        0        8.21
# 33        0       10.33
# 37       20       24.16
# 40        0       16.11
# 60        2        8.01
# 62       20       13.87
# 76        0        3.00
# 86        0        1.36
# 91        0        4.00
# 95        0        6.93
# 99        0        9.17
# 113       0        2.93
# 143       0        5.14
# 145       0        5.30
# 148       0        6.85
# 161       0        3.00
# 187       1       10.29
# 222       0        8.95
# 269       0        6.71
# 282      32       11.18
# 285      20        4.70
# 286      13        0.94
# 294      20        3.36
# 297      30        8.99
# 305       0       12.75
# 307       0       13.18
# 317       0        3.36
# 324       0        4.03
# 336       0       12.30
# 345      15        5.57
# 359      30        6.85
# 373      20        5.82
# 374       0       14.12
# 392       0        8.43
# 396       7       11.54
# 398       1        3.89
# 412      26       16.93
# 414      21        4.90
# 435       2       14.72
# 443       4       12.33
# 449       0       15.32
# 481       0        0.11
# 482       0       10.29
# 499       1        5.82
# 509       5        9.31
# 512       1        1.90
# 521       0        6.02

# %%
print(json.dumps(hotel_places, indent=4, sort_keys=True))
# Out:
# {
#     "html_attributions": [],
#     "next_page_token": "CqQCGgEAABIdfXlvllZ6AFPDARitM2sKXqDdw00DDcPDv1R4ZE8hDjk0cC0TaE22VfRl-XxImfB0ZsGPu_V8vzgtzJ4hlcDYF1jvwP4hw7P79YrjEuZiMGcZuighbePAYK_GeAhYqpmC5qKafkTocxpBZO5xlCIlKRmGwbph7hVGhnEHdaLryeW0WYxB5aFCmBAIQtd0rKbySBB2aZil8M_NLRvggofS7_JP3CojEAfk741NhbQ3RrLL2Y3MBASmFHSP78tYnqsYuhc9WzWcc2b4qKhzQKs8RXE4xrDDB_QQDeeJvvWXDKLvCGciaLxFB50Z3yNlVxEqWUj50MT0ynI6VpZuhsaPjjDLyo3CrgaugYyZai5-q8vXx9XAslorMCKN16T9wBIQ2BturGjVfK22hl8wBXlpUBoUMkyeF_K0ycRmQ9sOoZCmOZGGZ-4",
#     "results": [
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -22.6658429,
#                     "lng": 167.4960078
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -22.6580961,
#                         "lng": 167.5077617
#                     },
#                     "southwest": {
#                         "lat": -22.6750454,
#                         "lng": 167.4811649
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/geocode-71.png",
#             "id": "9c43a44d98f23c83db7418983e9701f5f36cb2f7",
#             "name": "Vao",
#             "photos": [
#                 {
#                     "height": 3918,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/110753004151330174839\">Karl Dpr</a>"
#                     ],
#                     "photo_reference": "CmRaAAAASs8kpnCBJ0mxy11WbKV7prUi_I5XkmXYi8Oi5ootPM1jjnYs39YxSuZ5g6YVwqsAYeyXz36ZtHWYs7eVKUSODvqm5pBaq6ES11DJTr87ZVih8TNpdUZ-i7Q2UQchLLLPEhDJJ75f5Ch8VTFVlafdxN5ZGhT_r8NjNBBcuV4MhpgkUCYqd7eyvQ",
#                     "width": 2939
#                 }
#             ],
#             "place_id": "ChIJLeO5l-y8KWwRyw0Vhfmd7tk",
#             "reference": "ChIJLeO5l-y8KWwRyw0Vhfmd7tk",
#             "scope": "GOOGLE",
#             "types": [
#                 "locality",
#                 "political"
#             ],
#             "vicinity": "Vao"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -22.659695,
#                     "lng": 167.443914
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -22.65830361970849,
#                         "lng": 167.4450214802915
#                     },
#                     "southwest": {
#                         "lat": -22.6610015802915,
#                         "lng": 167.4423235197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "2fad9cec4b4c9b21242ac471597acc7272220947",
#             "name": "Hotel Kou-Bugny",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 720,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/101369996858260665526\">Hotel Kou-Bugny</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAEWiWm6j5jsL56k2n0sGj-vsY5JZ_PjXf_xZWzVy2badl3vgjdixbP5Z2LgQa2Q5L7pqpPLsl3wEgfi4g1-a7ZGq76TFJnSuJgvafLiWoPO2mz67nhysHaJSW7_37lV0mEhBP7sNZGEEdQPko0Z9hVH4fGhSGuI6DaxYu00fBcoHMBlsEwDBmVg",
#                     "width": 960
#                 }
#             ],
#             "place_id": "ChIJLxT0ZBK7KWwRy_kVVGFcVSs",
#             "plus_code": {
#                 "compound_code": "8CRV+4H Kuto, New Caledonia",
#                 "global_code": "5V998CRV+4H"
#             },
#             "rating": 4,
#             "reference": "ChIJLxT0ZBK7KWwRy_kVVGFcVSs",
#             "scope": "GOOGLE",
#             "types": [
#                 "car_rental",
#                 "travel_agency",
#                 "lodging",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 123,
#             "vicinity": "Kuto"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -22.6642886,
#                     "lng": 167.4490816
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -22.66318736970849,
#                         "lng": 167.4503146302915
#                     },
#                     "southwest": {
#                         "lat": -22.6658853302915,
#                         "lng": 167.4476166697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "e4fa49be61e064cfb83efd2317b13c2a29101123",
#             "name": "OURE TERA beach resort",
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/114183561278597100338\">Marco D&#39;Angelo</a>"
#                     ],
#                     "photo_reference": "CmRaAAAACKGuljiatAjttKt__xslPEM3UyCODWI3tPJVzACaL20iG1vA3G0Jzxuhf_FuHmBkHwmR-mn_8Rf7BCBZ_DAuoL-IsL4buockgf6TPzPUb4XXb7BGVWeZQQkfHVquvL8IEhAiLHveTIBIYJc9NoRZpW1RGhRxGyOEXEwA1cI6wqwyYtWewHoPWg",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJ0cNYomy7KWwR9hAHs9VOC1w",
#             "plus_code": {
#                 "compound_code": "8CPX+7J Kuto, New Caledonia",
#                 "global_code": "5V998CPX+7J"
#             },
#             "rating": 4.4,
#             "reference": "ChIJ0cNYomy7KWwR9hAHs9VOC1w",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "bar",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 224,
#             "vicinity": "New Caledonia"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -22.6566111,
#                     "lng": 167.4442792
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -22.6550902697085,
#                         "lng": 167.4455599802915
#                     },
#                     "southwest": {
#                         "lat": -22.6577882302915,
#                         "lng": 167.4428620197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "62de393adcaedb5e43cfedf79a4910e81a8c13a0",
#             "name": "Village IGESA Kuto",
#             "photos": [
#                 {
#                     "height": 1960,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/105563928269824464012\">ninou ninou</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA6RjYrXN1Ce-x8I-Uv0PHgqT1pfWBp7G-Gq28tiwl33lv6ryMTLROz_pubGzQugd4bHMkEll7_dPoCKyQnlBcCPVlMCdZvl1igIcrK_cAh2OElwJRwrZ0mAWqSJHlAQbIEhBw1AiEh0Sq_hPP353NSx9_GhTxep_RGpIvhQat1KTBPVRCX0r3lA",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJzaIoBA27KWwRTT_1oIACbTc",
#             "plus_code": {
#                 "compound_code": "8CVV+9P Kuto, New Caledonia",
#                 "global_code": "5V998CVV+9P"
#             },
#             "rating": 4.2,
#             "reference": "ChIJzaIoBA27KWwRTT_1oIACbTc",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 54,
#             "vicinity": "Baie de Kuto BP 89, ILE-DES-PINS"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -22.662502,
#                     "lng": 167.4483883
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -22.6614972697085,
#                         "lng": 167.4497664802915
#                     },
#                     "southwest": {
#                         "lat": -22.6641952302915,
#                         "lng": 167.4470685197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "3e7e8b550f3e507cf51579d68aa54c187f07ac5f",
#             "name": "Nataiwatch Guest House",
#             "photos": [
#                 {
#                     "height": 1080,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/100883786112057841260\">Boris Grundler</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAgtopxo2KydEM59muZtxjPrbLW8VbWjlsRzEZSgv6eNMbzedWCwOjAe6g_xcXytryI0o6wI2-t29-cqO9tsw90IXDB_O0hlc0j4RpphZA4wRp-mCpbTfsgQcQFUsnReY7EhC3CfikAZOurlaNHzrgDPMhGhSLo_FDnLEwXPH9CkxzkURa-qOttQ",
#                     "width": 1920
#                 }
#             ],
#             "place_id": "ChIJ99sQ3Gy7KWwROcXY1VWi8Ig",
#             "plus_code": {
#                 "compound_code": "8CPX+X9 Kuto, New Caledonia",
#                 "global_code": "5V998CPX+X9"
#             },
#             "rating": 4.5,
#             "reference": "ChIJ99sQ3Gy7KWwROcXY1VWi8Ig",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 63,
#             "vicinity": "Kuto"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -22.6693308,
#                     "lng": 167.4869079
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -22.6679357697085,
#                         "lng": 167.4895185
#                     },
#                     "southwest": {
#                         "lat": -22.6706337302915,
#                         "lng": 167.4860377
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png",
#             "id": "b79d71ac5db15821140f03b16c86a3f7b4f2045a",
#             "name": "Sanctuaire Notre Dame de la Salette",
#             "photos": [
#                 {
#                     "height": 2448,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/114295715998237207932\">Jay Nicholson</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAkNjjz2T6GfAzAcUgWUJ5vUr8EedUKmAXunGG_acjOzdcYsRhPbAKDpfP6jzppMLIKyrddUwdPrlrZUPm3cri6sxJ5V_0ksVl6r6gCkgoTTp98YTS13UKvLEBbWslkQA5EhAFNF4jQ9lKPNw-g4Ph6FPJGhQrhYS_E8r_ZDAxk3BVzd8J0lC_Lw",
#                     "width": 3264
#                 }
#             ],
#             "place_id": "ChIJU0lggMS9KWwRe-lEAjjXsbY",
#             "plus_code": {
#                 "compound_code": "8FJP+7Q Vao, New Caledonia",
#                 "global_code": "5V998FJP+7Q"
#             },
#             "rating": 5,
#             "reference": "ChIJU0lggMS9KWwRe-lEAjjXsbY",
#             "scope": "GOOGLE",
#             "types": [
#                 "place_of_worship",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1,
#             "vicinity": "Vao"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -22.6697914,
#                     "lng": 167.471908
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -22.6683982697085,
#                         "lng": 167.4732971302915
#                     },
#                     "southwest": {
#                         "lat": -22.6710962302915,
#                         "lng": 167.4705991697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png",
#             "id": "bb5e74332761d922dc8d807609e85b866a65f02c",
#             "name": "Point de vue \u00celot Brosse",
#             "photos": [
#                 {
#                     "height": 1777,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/106365411699314924698\">PJ L</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA2ddir6L1ZLS6B8L8RQIo_OmoXsMET1v-cYkxx5D24DSu7EOGVwbWQm0vJTEG038dLcyZa58q-4CuObdFgsOn3w7l0wKmp8M4sVsWuKrUJghz9oXm7Om5qskJeoK6QrxjEhAXFNg_EpwmWOV541zvphcRGhTSo0ue5yY_kA6ODgTXezKSHounAA",
#                     "width": 3159
#                 }
#             ],
#             "place_id": "ChIJo7kxWoy9KWwRegzGcU9YSSo",
#             "plus_code": {
#                 "compound_code": "8FJC+3Q Kuto, New Caledonia",
#                 "global_code": "5V998FJC+3Q"
#             },
#             "reference": "ChIJo7kxWoy9KWwRegzGcU9YSSo",
#             "scope": "GOOGLE",
#             "types": [
#                 "tourist_attraction",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "New Caledonia"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -22.6714463,
#                     "lng": 167.4879799
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -22.6703092697085,
#                         "lng": 167.4895238802915
#                     },
#                     "southwest": {
#                         "lat": -22.67300723029151,
#                         "lng": 167.4868259197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png",
#             "id": "dfd688bd5bbc4ffae99ad720a60ede7b4ab3f42d",
#             "name": "Enercal - Base \u00cele des Pins",
#             "place_id": "ChIJ69cOVsC9KWwRTvpIH-W-W6c",
#             "plus_code": {
#                 "compound_code": "8FHQ+C5 Vao, New Caledonia",
#                 "global_code": "5V998FHQ+C5"
#             },
#             "reference": "ChIJ69cOVsC9KWwRTvpIH-W-W6c",
#             "scope": "GOOGLE",
#             "types": [
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Vao"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -22.6690407,
#                     "lng": 167.4882395
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -22.6677364697085,
#                         "lng": 167.4897982302915
#                     },
#                     "southwest": {
#                         "lat": -22.6704344302915,
#                         "lng": 167.4871002697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png",
#             "id": "f7b760dc2760393f6cac3cc674b02071dc591361",
#             "name": "Eglise Notre-Dame de L'Assomption",
#             "photos": [
#                 {
#                     "height": 683,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/107597599933747618070\">Philippe Rebuffel</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAXcTORINu8dAmP9co38ayr127ozy2PlWwhuPSkU79ws1Kp4HJ1vbxnfomatMmMAhrzC1_prP-x02tW78PdWNaedLsg8xXo-89VECsao3grTNAwtC4UQd-rBa2xx_h1CC2EhDz_sbTgp2hKa6yabDezwSnGhQLopFHEiPRuAv6yEAigx8EjfYTNQ",
#                     "width": 1024
#                 }
#             ],
#             "place_id": "ChIJv7he4ti9KWwRqrs5vcNurgo",
#             "plus_code": {
#                 "compound_code": "8FJQ+97 Vao, New Caledonia",
#                 "global_code": "5V998FJQ+97"
#             },
#             "rating": 5,
#             "reference": "ChIJv7he4ti9KWwRqrs5vcNurgo",
#             "scope": "GOOGLE",
#             "types": [
#                 "place_of_worship",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 2,
#             "vicinity": "Vao"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -22.6689808,
#                     "lng": 167.488278
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -22.66768846970849,
#                         "lng": 167.4898235802915
#                     },
#                     "southwest": {
#                         "lat": -22.6703864302915,
#                         "lng": 167.4871256197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/worship_general-71.png",
#             "id": "fb44c588a16040cd7515f5639d6ecf6cabd08cf0",
#             "name": "Church",
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/105303200551925998966\">Luca Guagni</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAdxmhSN7uUYxuhDu9y47p-UoxZ6FDOE1ZDj_j6p3ce-jQfbm14oFkWajwBpaa-_sdANz677SyvSpC98Haw3JGkfvaJ1F62HpWJIwYBu-OU-FwIIDlwOI-A5BEOx_RSVUZEhDNVIQy3Nd5LgY8VCt7zyPOGhRVN2NOE7xMHnQlDEdr59ssZcjAaw",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJGZgSu5a8KWwRpMsKJsqGPhE",
#             "plus_code": {
#                 "compound_code": "8FJQ+C8 Vao, New Caledonia",
#                 "global_code": "5V998FJQ+C8"
#             },
#             "rating": 3.9,
#             "reference": "ChIJGZgSu5a8KWwRpMsKJsqGPhE",
#             "scope": "GOOGLE",
#             "types": [
#                 "church",
#                 "place_of_worship",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 13,
#             "vicinity": "Vao"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -22.6700075,
#                     "lng": 167.4884743
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -22.6686064197085,
#                         "lng": 167.4899918802915
#                     },
#                     "southwest": {
#                         "lat": -22.6713043802915,
#                         "lng": 167.4872939197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/school-71.png",
#             "id": "1510ca9f1a765d48a52a8eab0fb3e9b53c624b19",
#             "name": "School Notre Dame Des Anges",
#             "photos": [
#                 {
#                     "height": 1920,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/107665358002114776607\">Olivier ROBERT-TRA\u00cbGER</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA0RJr_Q-RYR6H28tcArLwLgbo_p2ZQNP76TtJFThDvc32qR_r0SyuRRCGYZP_k4iAA4r9dvVuig6aBOk3MBsSDjWCJGdfmdnFYIabgbzCnE02Qn5ua7gGsOQWfjpXv08_EhBssmRJY4wHuastYh3AB50wGhSsOfaPt7gCgeYUZF_7m-fmyGubig",
#                     "width": 2560
#                 }
#             ],
#             "place_id": "ChIJmYr_O5S8KWwRkmUt5IclyUs",
#             "plus_code": {
#                 "compound_code": "8FHQ+X9 Vao, New Caledonia",
#                 "global_code": "5V998FHQ+X9"
#             },
#             "reference": "ChIJmYr_O5S8KWwRkmUt5IclyUs",
#             "scope": "GOOGLE",
#             "types": [
#                 "school",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Vao"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -22.67067339999999,
#                     "lng": 167.4890386
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -22.6693198197085,
#                         "lng": 167.4904024302915
#                     },
#                     "southwest": {
#                         "lat": -22.6720177802915,
#                         "lng": 167.4877044697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png",
#             "id": "d868b35ee71e0fb99287f7892bbb544d32743724",
#             "name": "Pharmacy",
#             "photos": [
#                 {
#                     "height": 1080,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/113976746340326481355\">Philip Ivanier</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAxkASZuU0tpYBe21ghiSXQmAxWKUopYaRyqn3pBzrj_ghioUrF5EEezBSY1avTyqOrvR-eg7cxD12bV29UJPE9o0Sfhm5-psnyggbNIiw_GMj5e8M1ymKTet_JytefgAwEhDaTOSj1xtKHY_DEhvYdyFZGhQ_Fj-Lx3tdJ0CkPh7CydIT2tLXlQ",
#                     "width": 1920
#                 }
#             ],
#             "place_id": "ChIJSQfUXnW9KWwRysZ5EiJEU7Y",
#             "plus_code": {
#                 "compound_code": "8FHQ+PJ Vao, New Caledonia",
#                 "global_code": "5V998FHQ+PJ"
#             },
#             "reference": "ChIJSQfUXnW9KWwRysZ5EiJEU7Y",
#             "scope": "GOOGLE",
#             "types": [
#                 "health",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Vao"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -22.6718354,
#                     "lng": 167.4889169
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -22.67037081970849,
#                         "lng": 167.4901488802915
#                     },
#                     "southwest": {
#                         "lat": -22.6730687802915,
#                         "lng": 167.4874509197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/cafe-71.png",
#             "id": "cc3a6b55b94fcea1d045ddbb1457858a6bfd468a",
#             "name": "Le petit creux",
#             "photos": [
#                 {
#                     "height": 1080,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/103023536617594386133\">Yvan Kouathe</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAUAJU4yscE54qdlUHwsBZrOKe-ZOevWFdjq0z1-bFcA86SQjTkJEbL2iO6nZtzOtx80BcMDyaOAEVAd2W4cuRj2wP6iyBLP08vApPFHy0LKMyp9j19G2wxzCGNHET6aHHEhCRhW4Go9yAnHb1b-tC8ir-GhTCifqid8U8u8oTFEuufJCWV-aWuA",
#                     "width": 1920
#                 }
#             ],
#             "place_id": "ChIJ39sKic-9KWwRBd63RDUkL9s",
#             "plus_code": {
#                 "compound_code": "8FHQ+7H Vao, New Caledonia",
#                 "global_code": "5V998FHQ+7H"
#             },
#             "reference": "ChIJ39sKic-9KWwRBd63RDUkL9s",
#             "scope": "GOOGLE",
#             "types": [
#                 "cafe",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Vao"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -22.6718923,
#                     "lng": 167.4889236
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -22.6704110197085,
#                         "lng": 167.4901386302915
#                     },
#                     "southwest": {
#                         "lat": -22.6731089802915,
#                         "lng": 167.4874406697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "69719e674c9980362a3cfb8e7689c5b91897a39b",
#             "name": "Le petit creux",
#             "photos": [
#                 {
#                     "height": 1080,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/103023536617594386133\">Yvan Kouathe</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAWW6W2y2hOeriX022B__5DeVhieIiwAmisJbFo2tsAmB4_dYfNnqSLXeSsgh3UkyQHTOoqxTyS-O5oK8hT8Rx7jLfT2VXK4oqae9k-g29zwAQxAHoCDBDrlyySFwKGwIdEhBD1njorMqQqsMCJQ06l0VsGhR_DX4quHMUGgfnngJ4SnE3nS4Wxg",
#                     "width": 1920
#                 }
#             ],
#             "place_id": "ChIJg7HlqXm9KWwRHDF-OQHgoAE",
#             "plus_code": {
#                 "compound_code": "8FHQ+6H Vao, New Caledonia",
#                 "global_code": "5V998FHQ+6H"
#             },
#             "rating": 1,
#             "reference": "ChIJg7HlqXm9KWwRHDF-OQHgoAE",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1,
#             "vicinity": "Vao"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -22.668876,
#                     "lng": 167.489608
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -22.6675199197085,
#                         "lng": 167.4910250302915
#                     },
#                     "southwest": {
#                         "lat": -22.6702178802915,
#                         "lng": 167.4883270697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/bank_dollar-71.png",
#             "id": "e22ed0e35dc077ca1845b1ed9bfdf9918f6964d3",
#             "name": "BCI Agence de l'Ile des Pins - Distributeur BCI de l'Ile des Pins",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 3096,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/111274874370931277423\">C\u00e9cile Touz\u00e9</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA-YMJaFjZxVH6t2_u6cWUwda9NQ1dRR1yM3vE2CCcINtrYrnvMIUPD-HIZ_xjeogSKoiNUcqy3Ic4g8MYBuL4yUImw0hGIA5dcNOB5ercomAyWCQe9QCrWibIKXjCDV1xEhChi1R_bO0CGEQRiKvXoBKOGhTSxyKzn0bUENBZCeOE7Oq5YbzzWA",
#                     "width": 4128
#                 }
#             ],
#             "place_id": "ChIJVWz1EJS8KWwRYHom1p01EwU",
#             "plus_code": {
#                 "compound_code": "8FJQ+CR Vao, New Caledonia",
#                 "global_code": "5V998FJQ+CR"
#             },
#             "rating": 5,
#             "reference": "ChIJVWz1EJS8KWwRYHom1p01EwU",
#             "scope": "GOOGLE",
#             "types": [
#                 "bank",
#                 "finance",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1,
#             "vicinity": "Vao"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -22.6689619,
#                     "lng": 167.4900591
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -22.6676110697085,
#                         "lng": 167.4914671802915
#                     },
#                     "southwest": {
#                         "lat": -22.6703090302915,
#                         "lng": 167.4887692197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png",
#             "id": "bbe727df24461a8f94a6d3700ea5016bb0b0eb54",
#             "name": "marche de vao",
#             "photos": [
#                 {
#                     "height": 3036,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/115882020912892936597\">Glenn Batten</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAhtxddQQl12DBi7hvzh1tb7JtDw02y30RKgxFLr8VY6RM_wcLT-9Pu8ANaselLET24iF6SmuhbP-mD__NTR-XlhqJNbjaCwpEroa4dqURwavjVoxgQKGLGiOunXr-oXXVEhC0UmWAIF4v1b3qBL1x6CrKGhSNubF-cJBoqhMPxnuIiZV_Di-_RA",
#                     "width": 4048
#                 }
#             ],
#             "place_id": "ChIJB4ncfJS8KWwRy0AAWipDJK0",
#             "plus_code": {
#                 "compound_code": "8FJR+C2 Vao, New Caledonia",
#                 "global_code": "5V998FJR+C2"
#             },
#             "rating": 4.6,
#             "reference": "ChIJB4ncfJS8KWwRy0AAWipDJK0",
#             "scope": "GOOGLE",
#             "types": [
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 5,
#             "vicinity": "New Caledonia"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -22.6678411,
#                     "lng": 167.4931812
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -22.66646571970849,
#                         "lng": 167.4945227802915
#                     },
#                     "southwest": {
#                         "lat": -22.6691636802915,
#                         "lng": 167.4918248197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png",
#             "id": "e75d9089bd1bde2a64383c557f8e0ec509d7c433",
#             "name": "Epicerie Saint-Mathieu",
#             "photos": [
#                 {
#                     "height": 2560,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/114822137807840859780\">denis Tikoure</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAgKu1k658dcwQRVwacT00UcrnBZcOo8BDdoEk5mG-Kxu472wQoSYY9s_vqntrOm5iyrdqBpnLMiILd26bzAiQlwjw1a0TJ-7Wu1Y0QjjzXiigh6n_sa7iwrbPdVIIAY0NEhDWjBteMjF4CVuEA22mRWlCGhSfJ2deptFPgjoQI5VIN6g7CXBsFw",
#                     "width": 1536
#                 }
#             ],
#             "place_id": "ChIJPbFQrey8KWwRbRtF6RtHrUw",
#             "plus_code": {
#                 "compound_code": "8FJV+V7 Vao, New Caledonia",
#                 "global_code": "5V998FJV+V7"
#             },
#             "rating": 3.4,
#             "reference": "ChIJPbFQrey8KWwRbRtF6RtHrUw",
#             "scope": "GOOGLE",
#             "types": [
#                 "grocery_or_supermarket",
#                 "food",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 5,
#             "vicinity": "Vao"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -22.6642891,
#                     "lng": 167.492756
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -22.6629243697085,
#                         "lng": 167.4940138802915
#                     },
#                     "southwest": {
#                         "lat": -22.6656223302915,
#                         "lng": 167.4913159197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png",
#             "id": "10bb04fbc0152a6584d50b33f57dadcab10b3bd7",
#             "name": "Kuni\u00e9 Island",
#             "place_id": "ChIJdcODyZK8KWwR5m9mkzbriyY",
#             "plus_code": {
#                 "compound_code": "8FPV+74 Vao, New Caledonia",
#                 "global_code": "5V998FPV+74"
#             },
#             "reference": "ChIJdcODyZK8KWwR5m9mkzbriyY",
#             "scope": "GOOGLE",
#             "types": [
#                 "travel_agency",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Vao"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -22.6735341,
#                     "lng": 167.4939721
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -22.67215746970849,
#                         "lng": 167.4952153302915
#                     },
#                     "southwest": {
#                         "lat": -22.6748554302915,
#                         "lng": 167.4925173697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png",
#             "id": "456ccdf418bf08c06276b84c616f9c294758e798",
#             "name": "Saint Maurice",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/105196264621334747010\">Silvio Casagrande</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA2ozG1jiTbhXyLi7XJuCQZQqO0ord2sEh4EiT-ijXyqI2lnvOSEYtKNXybZ-NYUEVTOhteBjoXKjCSGtAb8FjQTmHJ0qmx2BRdjS5aQv-CEONCU0zzcVwGeUN8Gkc6oxLEhAvDToJL5bSs0w6mp22fcRuGhSoaFhGDbIKQxRFlDybxy8PUrxImg",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJB0ZZuuq8KWwR_qTzHmcmndE",
#             "plus_code": {
#                 "compound_code": "8FGV+HH Vao, New Caledonia",
#                 "global_code": "5V998FGV+HH"
#             },
#             "rating": 4.5,
#             "reference": "ChIJB0ZZuuq8KWwR_qTzHmcmndE",
#             "scope": "GOOGLE",
#             "types": [
#                 "tourist_attraction",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 33,
#             "vicinity": "Vao"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -22.66063979999999,
#                     "lng": 167.4486838
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -22.6487693,
#                         "lng": 167.4647391
#                     },
#                     "southwest": {
#                         "lat": -22.667878,
#                         "lng": 167.4362969
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/geocode-71.png",
#             "id": "40c48ce5ca975725a2d6f3e318f9941b035ed88e",
#             "name": "Kuto",
#             "photos": [
#                 {
#                     "height": 683,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/107597599933747618070\">Philippe Rebuffel</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAaMMZtwkmzv8XzPZafxy5cf3NM8NN1VvdiCSV2binnEX9pAI8mk05Cd-N0VlEV90ckw0LnYhxtJ0cM732DdUPXa8O2snoaLIUcSQqSdfHtVItuMAkp9BMnnZ1oVaoOsSDEhAC3CfoY6RKA0CxFWaowwOcGhTHfL1la9YNl3brldvb8RVt6lELZA",
#                     "width": 1024
#                 }
#             ],
#             "place_id": "ChIJo_dt8w-7KWwRAf3qqLOimu0",
#             "reference": "ChIJo_dt8w-7KWwRAf3qqLOimu0",
#             "scope": "GOOGLE",
#             "types": [
#                 "locality",
#                 "political"
#             ],
#             "vicinity": "Kuto"
#         }
#     ],
#     "status": "OK"
# }

# %%
hotel_map = hotel_places[""]

markers = hotel_places[['Latitude', 'Longitude']]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-2ee6a263a3d8> in <module>
# ----> 1 markers = hotel_places[['Latitude', 'Longitude']]
#
# TypeError: unhashable type: 'list'

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
#add market layer ontop of heatmap, display figure
