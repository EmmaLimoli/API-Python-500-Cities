# %% [markdown]
# * Create a heat map that displays the humidity for every city from the part I of the homework.
#
# * Narrow down the DataFrame to find your ideal weather condition. For example:
#
#   * A max temperature lower than 80 degrees but higher than 70.
#
#   * Wind speed less than 10 mph.
#
#   * Zero cloudiness.
#
#   * Drop any rows that don't contain all three conditions. You want to be sure the weather is ideal.
#
#   * **Note:** Feel free to adjust to your specifications but be sure to limit the number of rows returned by your API requests to a reasonable number.
#
# * Using Google Places API to find the first hotel for each city located within 5000 meters of your coordinates.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import json

# Import API key
from api_keys import g_key
# g_key

# %%
#load the csv from Part 1 into a dataframe
weather_data_df = pd.read_csv("../weather_py/output_data/weatherPy_clean_data.csv") 
weather_data_df.head()
# Out:
#           City Country    Lat     Lon  Max Temp  Humidity        Date  Clouds  \
# 0  new norfolk      AU -42.78  147.06     44.01        80  1595339792      83
# 1        kapaa      US  22.08 -159.32     75.20        83  1595340131      40
# 2   nouadhibou      MR  20.93  -17.03     80.60        69  1595340133       1
# 3    saskylakh      RU  71.92  114.08     49.87        77  1595340134     100
# 4  olovyannaya      RU  50.95  115.57     60.75        56  1595340136      31
#
#    Wind Speed
# 0        1.99
# 1        8.05
# 2       12.75
# 3        9.51
# 4        3.83

# %%
#configure map
gmaps.configure(api_key=g_key)

# %%
#create humidity heat map, configre gmaps, use lat/lng as locations and humidity as weight, add heatmap layer to map

locations = weather_data_df[["Lat", "Lon"]]
weights = weather_data_df["Humidity"]

fig = gmaps.figure()

heat_map = gmaps.heatmap_layer(locations, weights, dissipating=False, max_intensity=100, point_radius = 1)

fig.add_layer(heat_map)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#create new dataframe to fit weather criteria, do the loc, drop null values


myIdeal = ((weather_data_df['Max Temp'] >= 60) & (weather_data_df['Max Temp'] <=75) & (weather_data_df['Clouds'] <40) & 
    (weather_data_df['Humidity'] <=80)) 
myIdeal.value_counts()
# Out:
# False    507
# True      60
# dtype: int64

# %%
#dataframe for perfect vacation
perfect_vaca = weather_data_df.loc[myIdeal, :]

hotel_df = perfect_vaca.dropna(how="any")
hotel_df.count()

hotel_df
# Out:
#                   City Country    Lat     Lon  Max Temp  Humidity        Date  \
# 4          olovyannaya      RU  50.95  115.57     60.75        56  1595340136
# 14              winton      US  37.39 -120.61     64.99        68  1595340153
# 19           kununurra      AU -15.77  128.73     60.80        26  1595340159
# 36           cape town      ZA -33.93   18.42     71.01        59  1595340183
# 39          willowmore      ZA -33.29   23.49     72.63        19  1595340187
# 40            hermanus      ZA -34.42   19.23     66.99        62  1595339914
# 46        ponta do sol      PT  32.67  -17.10     73.99        60  1595340196
# 75            karratha      AU -20.74  116.85     67.95        64  1595340133
# 82         plettenberg      DE  51.22    7.88     68.00        49  1595340248
# 94            fengzhen      CN  40.44  113.15     67.64        60  1595340263
# 104        east london      ZA -33.02   27.91     69.80        73  1595340279
# 109           zyryanka      RU  65.75  150.85     70.11        41  1595340285
# 112           la tuque      CA  47.43  -72.78     64.17        51  1595340290
# 121             castro      BR -24.79  -50.01     70.50        53  1595340303
# 122           cidreira      BR -30.18  -50.21     69.80        68  1595340304
# 128            kutulik      RU  53.35  102.78     61.18        73  1595340314
# 138           saldanha      ZA -33.01   17.94     68.00        56  1595340328
# 157              kuito      AO -12.38   16.93     71.60        19  1595340354
# 164     port elizabeth      ZA -33.92   25.57     68.00        64  1595340364
# 172         baruun-urt      MN  46.68  113.28     63.93        67  1595340375
# 187             kwekwe      ZW -18.93   29.81     74.57        20  1595340395
# 194             khasan      RU  42.43  130.64     69.35        78  1595340405
# 201           bulawayo      ZW -20.15   28.58     69.98        24  1595340415
# 223             beloha      MG -25.17   45.05     68.20        58  1595340445
# 229              lagoa      PT  39.05  -27.98     68.38        73  1595340454
# 239           thompson      CA  55.74  -97.86     64.40        77  1595340467
# 261        port alfred      ZA -33.59   26.89     72.16        48  1595340495
# 265           portland      US  45.52 -122.68     64.99        77  1595340424
# 273           verlaine      BE  50.61    5.32     73.00        37  1595340511
# 275               kyra      RU  49.58  111.98     60.66        74  1595340514
# 288          mount isa      AU -20.73  139.50     64.40        27  1595340533
# 307      srednekolymsk      RU  67.45  153.68     65.34        45  1595340557
# 330        walla walla      US  46.06 -118.34     70.00        52  1595340405
# 364        farafangana      MG -22.82   47.83     67.98        70  1595340637
# 369            barsovo      RU  61.17   73.17     71.60        46  1595340644
# 381          ostrovnoy      RU  68.05   39.51     71.19        49  1595340663
# 382             panjab      AF  34.39   67.02     66.70        25  1595340664
# 401           antalaha      MG -14.90   50.28     72.68        64  1595340691
# 408       pandamatenga      BW -18.53   25.63     74.44        23  1595340701
# 424               uvat      RU  59.14   68.90     71.35        55  1595340722
# 438             domoni      KM -12.26   44.53     74.32        74  1595340741
# 460         christiana      ZA -27.91   25.16     70.61        17  1595340770
# 470    baie-saint-paul      CA  47.44  -70.50     68.20        50  1595340597
# 476          roebourne      AU -20.78  117.13     68.13        63  1595340792
# 488      zelenoborskiy      RU  66.84   32.36     66.76        58  1595340808
# 493             fallon      US  39.47 -118.78     73.99        28  1595340796
# 494            margate      GB  51.38    1.39     72.00        47  1595340815
# 500         bonwapitse      BW -23.08   26.70     72.12        21  1595340824
# 507             bulgan      MN  48.81  103.53     64.18        63  1595340833
# 517           redlands      US  34.06 -117.18     66.20        72  1595340845
# 520          morondava      MG -20.28   44.28     73.49        71  1595340849
# 521               bend      US  44.06 -121.32     70.00        63  1595340798
# 532              igrim      RU  63.19   64.42     74.26        46  1595340866
# 534            erdenet      MN  49.03  104.08     63.10        68  1595340869
# 540             oswego      US  43.45  -76.15     73.99        73  1595340709
# 545  zverinogolovskoye      RU  54.46   64.85     69.73        67  1595340884
# 550             yongan      CN  39.70  113.69     64.17        74  1595340891
# 557            oshkosh      US  44.02  -88.54     69.80        64  1595340734
# 564            isangel      VU -19.55  169.27     69.01        74  1595340910
#
#      Clouds  Wind Speed
# 4        31        3.83
# 14        1        8.05
# 19        0        9.53
# 36        0       13.87
# 39        0       15.88
# 40        0        5.99
# 46        9        1.01
# 75        0        1.95
# 82        0        1.01
# 94        0        8.08
# 104       0       10.29
# 109       0       16.42
# 112       0        6.73
# 121       0        8.16
# 122       1        3.83
# 128       0        5.06
# 138       0        8.05
# 157       0        5.50
# 164       0       11.41
# 172       0       12.03
# 187       0        5.95
# 194       0        4.25
# 201       0        8.19
# 223       1       14.32
# 229       0        2.37
# 239      20        3.36
# 261       0       15.84
# 265      20        8.05
# 273       0        8.05
# 275       0        1.23
# 288      26       11.41
# 307       0       10.02
# 330       1        6.93
# 364       3        6.02
# 369       0       11.18
# 381       0       14.47
# 382       0       15.90
# 401      15       12.62
# 408       0        6.87
# 424       0        5.19
# 438      31       14.03
# 460       0        3.47
# 470      22        4.41
# 476       0        1.92
# 488      14       11.34
# 493       1        8.05
# 494      11        3.00
# 500       0        8.48
# 507       4        0.49
# 517       1        0.29
# 520       0        8.66
# 521       1        8.05
# 532       0        2.64
# 534       0        2.48
# 540       1        8.05
# 545      32       10.67
# 550       4        8.99
# 557       1       10.29
# 564      18       11.74

# %%
#create new hotel column, hotel_df["Hotel"] = ""
hotel_df.insert(9, "Hotel", "")

# %%
#new hotel column
hotel_df.head()
# Out:
#            City Country    Lat     Lon  Max Temp  Humidity        Date  \
# 4   olovyannaya      RU  50.95  115.57     60.75        56  1595340136
# 14       winton      US  37.39 -120.61     64.99        68  1595340153
# 19    kununurra      AU -15.77  128.73     60.80        26  1595340159
# 36    cape town      ZA -33.93   18.42     71.01        59  1595340183
# 39   willowmore      ZA -33.29   23.49     72.63        19  1595340187
#
#     Clouds  Wind Speed Hotel
# 4       31        3.83
# 14       1        8.05
# 19       0        9.53
# 36       0       13.87
# 39       0       15.88

# %%
#create hotel map, 5000 meters, use Places to find hotel, mark plots on heatmap, if there are more than 4-5 cities for loop

base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# target_coords = "-22.67, 167.48"
# target_type = "hotel"
# target_radius = 5000

params = {
    "keyword": "hotel",
    "radius": 5000,
    "type": "hotel",
    "key": g_key
}

for index, row in hotel_df.iterrows():
    lat = row["Lat"] 
    lon = row["Lon"]
    hotel_type = row["City"]
   
    params["location"] = f"{lat},{lon}"
    
    print(f"Retrieving Results From Index {index}: {hotel_type}.")
    response = requests.get(base_url, params=params).json()
    
    results = response["results"]
    
    try:
        print(f"Closest {hotel_type} hotel is {results[0]['name']}.")
        
        hotel_df.loc[index, "Hotel"] = results[0]["name"]
    
    except (KeyError, IndexError):
        print("Missing information...skipping")
        print("----------------")

print("Data Retrieval Complete")
print("------------------------")
# Out:
# Retrieving Results From Index 4: olovyannaya.
# Closest olovyannaya hotel is Gostinitsa.
# Retrieving Results From Index 14: winton.
# Closest winton hotel is Applegate Inn.
# Retrieving Results From Index 19: kununurra.
# Closest kununurra hotel is Freshwater East Kimberley Apartments | Kununurra Accommodation.
# Retrieving Results From Index 36: cape town.
# Closest cape town hotel is Atlanticview Cape Town Boutique Hotel.
# Retrieving Results From Index 39: willowmore.
# Closest willowmore hotel is Royal Hotel.
# Retrieving Results From Index 40: hermanus.
# Closest hermanus hotel is Harbour House Hotel.
# Retrieving Results From Index 46: ponta do sol.
# Closest ponta do sol hotel is Estalagem Da Ponta Do Sol.
# Retrieving Results From Index 75: karratha.
# Closest karratha hotel is Karratha International Hotel.
# Retrieving Results From Index 82: plettenberg.
# Closest plettenberg hotel is Hotel Weidenhof.
# Retrieving Results From Index 94: fengzhen.
# Closest fengzhen hotel is Feng Zhen Hotel.
# Retrieving Results From Index 104: east london.
# Closest east london hotel is Premier Hotel Regent.
# Retrieving Results From Index 109: zyryanka.
# Missing information...skipping
# ----------------
# Retrieving Results From Index 112: la tuque.
# Closest la tuque hotel is Hôtel Marineau La Tuque.
# Retrieving Results From Index 121: castro.
# Closest castro hotel is Hotel Alvorada.
# Retrieving Results From Index 122: cidreira.
# Closest cidreira hotel is Pond Country Club.
# Retrieving Results From Index 128: kutulik.
# Missing information...skipping
# ----------------
# Retrieving Results From Index 138: saldanha.
# Closest saldanha hotel is Blue Bay Lodge.
# Retrieving Results From Index 157: kuito.
# Closest kuito hotel is iu Hotel Kuíto.
# Retrieving Results From Index 164: port elizabeth.
# Closest port elizabeth hotel is Island Vibe Port Elizabeth.
# Retrieving Results From Index 172: baruun-urt.
# Closest baruun-urt hotel is tansag hotel.
# Retrieving Results From Index 187: kwekwe.
# Closest kwekwe hotel is Palm Leaf Gardens-Guest House.
# Retrieving Results From Index 194: khasan.
# Missing information...skipping
# ----------------
# Retrieving Results From Index 201: bulawayo.
# Closest bulawayo hotel is Holiday Inn Bulawayo.
# Retrieving Results From Index 223: beloha.
# Missing information...skipping
# ----------------
# Retrieving Results From Index 229: lagoa.
# Closest lagoa hotel is Graciosa Resort - Biosphere Island Hotel.
# Retrieving Results From Index 239: thompson.
# Closest thompson hotel is Best Western Thompson Hotel & Suites.
# Retrieving Results From Index 261: port alfred.
# Closest port alfred hotel is The Halyards Hotel.
# Retrieving Results From Index 265: portland.
# Closest portland hotel is River's Edge Hotel.
# Retrieving Results From Index 273: verlaine.
# Missing information...skipping
# ----------------
# Retrieving Results From Index 275: kyra.
# Missing information...skipping
# ----------------
# Retrieving Results From Index 288: mount isa.
# Closest mount isa hotel is Abacus Motel.
# Retrieving Results From Index 307: srednekolymsk.
# Missing information...skipping
# ----------------
# Retrieving Results From Index 330: walla walla.
# Closest walla walla hotel is Marcus Whitman Hotel & Conference Center.
# Retrieving Results From Index 364: farafangana.
# Closest farafangana hotel is Tsaravatsy Hotel.
# Retrieving Results From Index 369: barsovo.
# Missing information...skipping
# ----------------
# Retrieving Results From Index 381: ostrovnoy.
# Missing information...skipping
# ----------------
# Retrieving Results From Index 382: panjab.
# Missing information...skipping
# ----------------
# Retrieving Results From Index 401: antalaha.
# Closest antalaha hotel is Villa-Malaza.
# Retrieving Results From Index 408: pandamatenga.
# Closest pandamatenga hotel is Panda Rest Camp.
# Retrieving Results From Index 424: uvat.
# Closest uvat hotel is Gostinitsa Biatlon.
# Retrieving Results From Index 438: domoni.
# Closest domoni hotel is Al Djadid.
# Retrieving Results From Index 460: christiana.
# Closest christiana hotel is Vaal de Vue Guest House In Christiana.
# Retrieving Results From Index 470: baie-saint-paul.
# Closest baie-saint-paul hotel is Hôtel & Spa Le Germain Charlevoix.
# Retrieving Results From Index 476: roebourne.
# Closest roebourne hotel is Latitude20 Roebourne Village.
# Retrieving Results From Index 488: zelenoborskiy.
# Closest zelenoborskiy hotel is Motel Zeleniy Bor.
# Retrieving Results From Index 493: fallon.
# Closest fallon hotel is Comfort Inn & Suites Near Fallon Naval Air Station.
# Retrieving Results From Index 494: margate.
# Closest margate hotel is Sands Hotel Margate.
# Retrieving Results From Index 500: bonwapitse.
# Missing information...skipping
# ----------------
# Retrieving Results From Index 507: bulgan.
# Closest bulgan hotel is Bulgan Hotel.
# Retrieving Results From Index 517: redlands.
# Closest redlands hotel is Ayres Hotel Redlands.
# Retrieving Results From Index 520: morondava.
# Closest morondava hotel is Kimony Resort Hotel.
# Retrieving Results From Index 521: bend.
# Closest bend hotel is Tetherow.
# Retrieving Results From Index 532: igrim.
# Closest igrim hotel is Obshchezhitiye 3 Upts.
# Retrieving Results From Index 534: erdenet.
# Closest erdenet hotel is Erdenet Inn Hotel.
# Retrieving Results From Index 540: oswego.
# Closest oswego hotel is Feeder Creek Lodge and Cabin.
# Retrieving Results From Index 545: zverinogolovskoye.
# Missing information...skipping
# ----------------
# Retrieving Results From Index 550: yongan.
# Closest yongan hotel is Hengjili Hotel.
# Retrieving Results From Index 557: oshkosh.
# Closest oshkosh hotel is Hilton Garden Inn Oshkosh.
# Retrieving Results From Index 564: isangel.
# Closest isangel hotel is Quarumanu area.

# %%
#display new dataframe with hotel name added
hotel_df
# Out:
#                   City Country    Lat     Lon  Max Temp  Humidity        Date  \
# 4          olovyannaya      RU  50.95  115.57     60.75        56  1595340136
# 14              winton      US  37.39 -120.61     64.99        68  1595340153
# 19           kununurra      AU -15.77  128.73     60.80        26  1595340159
# 36           cape town      ZA -33.93   18.42     71.01        59  1595340183
# 39          willowmore      ZA -33.29   23.49     72.63        19  1595340187
# 40            hermanus      ZA -34.42   19.23     66.99        62  1595339914
# 46        ponta do sol      PT  32.67  -17.10     73.99        60  1595340196
# 75            karratha      AU -20.74  116.85     67.95        64  1595340133
# 82         plettenberg      DE  51.22    7.88     68.00        49  1595340248
# 94            fengzhen      CN  40.44  113.15     67.64        60  1595340263
# 104        east london      ZA -33.02   27.91     69.80        73  1595340279
# 109           zyryanka      RU  65.75  150.85     70.11        41  1595340285
# 112           la tuque      CA  47.43  -72.78     64.17        51  1595340290
# 121             castro      BR -24.79  -50.01     70.50        53  1595340303
# 122           cidreira      BR -30.18  -50.21     69.80        68  1595340304
# 128            kutulik      RU  53.35  102.78     61.18        73  1595340314
# 138           saldanha      ZA -33.01   17.94     68.00        56  1595340328
# 157              kuito      AO -12.38   16.93     71.60        19  1595340354
# 164     port elizabeth      ZA -33.92   25.57     68.00        64  1595340364
# 172         baruun-urt      MN  46.68  113.28     63.93        67  1595340375
# 187             kwekwe      ZW -18.93   29.81     74.57        20  1595340395
# 194             khasan      RU  42.43  130.64     69.35        78  1595340405
# 201           bulawayo      ZW -20.15   28.58     69.98        24  1595340415
# 223             beloha      MG -25.17   45.05     68.20        58  1595340445
# 229              lagoa      PT  39.05  -27.98     68.38        73  1595340454
# 239           thompson      CA  55.74  -97.86     64.40        77  1595340467
# 261        port alfred      ZA -33.59   26.89     72.16        48  1595340495
# 265           portland      US  45.52 -122.68     64.99        77  1595340424
# 273           verlaine      BE  50.61    5.32     73.00        37  1595340511
# 275               kyra      RU  49.58  111.98     60.66        74  1595340514
# 288          mount isa      AU -20.73  139.50     64.40        27  1595340533
# 307      srednekolymsk      RU  67.45  153.68     65.34        45  1595340557
# 330        walla walla      US  46.06 -118.34     70.00        52  1595340405
# 364        farafangana      MG -22.82   47.83     67.98        70  1595340637
# 369            barsovo      RU  61.17   73.17     71.60        46  1595340644
# 381          ostrovnoy      RU  68.05   39.51     71.19        49  1595340663
# 382             panjab      AF  34.39   67.02     66.70        25  1595340664
# 401           antalaha      MG -14.90   50.28     72.68        64  1595340691
# 408       pandamatenga      BW -18.53   25.63     74.44        23  1595340701
# 424               uvat      RU  59.14   68.90     71.35        55  1595340722
# 438             domoni      KM -12.26   44.53     74.32        74  1595340741
# 460         christiana      ZA -27.91   25.16     70.61        17  1595340770
# 470    baie-saint-paul      CA  47.44  -70.50     68.20        50  1595340597
# 476          roebourne      AU -20.78  117.13     68.13        63  1595340792
# 488      zelenoborskiy      RU  66.84   32.36     66.76        58  1595340808
# 493             fallon      US  39.47 -118.78     73.99        28  1595340796
# 494            margate      GB  51.38    1.39     72.00        47  1595340815
# 500         bonwapitse      BW -23.08   26.70     72.12        21  1595340824
# 507             bulgan      MN  48.81  103.53     64.18        63  1595340833
# 517           redlands      US  34.06 -117.18     66.20        72  1595340845
# 520          morondava      MG -20.28   44.28     73.49        71  1595340849
# 521               bend      US  44.06 -121.32     70.00        63  1595340798
# 532              igrim      RU  63.19   64.42     74.26        46  1595340866
# 534            erdenet      MN  49.03  104.08     63.10        68  1595340869
# 540             oswego      US  43.45  -76.15     73.99        73  1595340709
# 545  zverinogolovskoye      RU  54.46   64.85     69.73        67  1595340884
# 550             yongan      CN  39.70  113.69     64.17        74  1595340891
# 557            oshkosh      US  44.02  -88.54     69.80        64  1595340734
# 564            isangel      VU -19.55  169.27     69.01        74  1595340910
#
#      Clouds  Wind Speed                                              Hotel
# 4        31        3.83                                         Gostinitsa
# 14        1        8.05                                      Applegate Inn
# 19        0        9.53  Freshwater East Kimberley Apartments | Kununur...
# 36        0       13.87              Atlanticview Cape Town Boutique Hotel
# 39        0       15.88                                        Royal Hotel
# 40        0        5.99                                Harbour House Hotel
# 46        9        1.01                          Estalagem Da Ponta Do Sol
# 75        0        1.95                       Karratha International Hotel
# 82        0        1.01                                    Hotel Weidenhof
# 94        0        8.08                                    Feng Zhen Hotel
# 104       0       10.29                               Premier Hotel Regent
# 109       0       16.42
# 112       0        6.73                            Hôtel Marineau La Tuque
# 121       0        8.16                                     Hotel Alvorada
# 122       1        3.83                                  Pond Country Club
# 128       0        5.06
# 138       0        8.05                                     Blue Bay Lodge
# 157       0        5.50                                     iu Hotel Kuíto
# 164       0       11.41                         Island Vibe Port Elizabeth
# 172       0       12.03                                       tansag hotel
# 187       0        5.95                      Palm Leaf Gardens-Guest House
# 194       0        4.25
# 201       0        8.19                               Holiday Inn Bulawayo
# 223       1       14.32
# 229       0        2.37           Graciosa Resort - Biosphere Island Hotel
# 239      20        3.36               Best Western Thompson Hotel & Suites
# 261       0       15.84                                 The Halyards Hotel
# 265      20        8.05                                 River's Edge Hotel
# 273       0        8.05
# 275       0        1.23
# 288      26       11.41                                       Abacus Motel
# 307       0       10.02
# 330       1        6.93           Marcus Whitman Hotel & Conference Center
# 364       3        6.02                                   Tsaravatsy Hotel
# 369       0       11.18
# 381       0       14.47
# 382       0       15.90
# 401      15       12.62                                       Villa-Malaza
# 408       0        6.87                                    Panda Rest Camp
# 424       0        5.19                                 Gostinitsa Biatlon
# 438      31       14.03                                          Al Djadid
# 460       0        3.47              Vaal de Vue Guest House In Christiana
# 470      22        4.41                  Hôtel & Spa Le Germain Charlevoix
# 476       0        1.92                       Latitude20 Roebourne Village
# 488      14       11.34                                  Motel Zeleniy Bor
# 493       1        8.05  Comfort Inn & Suites Near Fallon Naval Air Sta...
# 494      11        3.00                                Sands Hotel Margate
# 500       0        8.48
# 507       4        0.49                                       Bulgan Hotel
# 517       1        0.29                               Ayres Hotel Redlands
# 520       0        8.66                                Kimony Resort Hotel
# 521       1        8.05                                           Tetherow
# 532       0        2.64                              Obshchezhitiye 3 Upts
# 534       0        2.48                                  Erdenet Inn Hotel
# 540       1        8.05                       Feeder Creek Lodge and Cabin
# 545      32       10.67
# 550       4        8.99                                     Hengjili Hotel
# 557       1       10.29                          Hilton Garden Inn Oshkosh
# 564      18       11.74                                     Quarumanu area

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lon"]]

# %%
#add market layer ontop of heatmap, display figure
locations = hotel_df[["Lat", "Lon"]]
weights = hotel_df["Humidity"]

fig = gmaps.figure()
markers = gmaps.marker_layer(locations)
                         

fig.add_layer(markers)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
