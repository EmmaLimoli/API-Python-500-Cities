# %% [markdown]
# * Randomly select **at least** 500 unique (non-repeat) cities based on latitude and longitude.
# * Perform a weather check on each of the cities using a series of successive API calls.
# * Include a print log of each city as it's being processed with the city number and city name.
# * Save a CSV of all retrieved data and a PNG image for each scatter plot.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# weather_api_key

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 611

# %%
print(cities)
# Out:
# ['coahuayana', 'dingle', 'ribeira grande', 'botwood', 'hilo', 'atuona', 'rikitea', 'ushuaia', 'sobolevo', 'kodiak', 'luganville', 'chicama', 'punta arenas', 'mataura', 'busselton', 'jalu', 'zhigansk', 'balagansk', 'east london', 'kavieng', 'clyde river', 'port alfred', 'chuy', 'hobart', 'mocuba', 'sao mateus do sul', 'marquette', 'smidovich', 'kruisfontein', 'salinopolis', 'albany', 'liusha', 'atikokan', 'bredasdorp', 'satitoa', 'tsihombe', 'dikson', 'maniwaki', 'vaini', 'necochea', 'sur', 'saint-philippe', 'barroualie', 'barrow', 'petropavlovsk-kamchatskiy', 'seoul', 'beloha', 'whyalla', 'butaritari', 'buchanan', 'kloulklubed', 'sarangani', 'jamestown', 'pisco', 'kerman', 'hovd', 'tuktoyaktuk', 'touros', 'nanortalik', 'carndonagh', 'maneadero', 'severo-kurilsk', 'puerto ayora', 'kapaa', 'port blair', 'vila franca do campo', 'narsaq', 'lamballe', 'victoria', 'port elizabeth', 'inhambane', 'cabo san lucas', 'loksa', 'belaya gora', 'port hardy', 'zemio', 'avera', 'college', 'halden', 'new norfolk', 'sataua', 'jeremie', 'bulgan', 'bilma', 'quatre cocos', 'voh', 'brae', 'grindavik', 'mahebourg', 'nizhneyansk', 'provideniya', 'meyungs', 'slave lake', 'sri aman', 'saint george', 'anadyr', 'prince albert', 'cochrane', 'ponta do sol', 'tiarei', 'te anau', 'mar del plata', 'san cristobal', 'hamilton', 'hermanus', 'mount gambier', 'ovalle', 'manicore', 'jiangyou', 'cape town', 'mount isa', 'sao filipe', 'akureyri', 'port hedland', 'carnarvon', 'palana', 'longyearbyen', 'faanui', 'bathsheba', 'avarua', 'lima', 'taolanaro', 'georgetown', 'saskylakh', 'krasnoselkup', 'gwadar', 'ancud', 'lumby', 'panlaitan', 'cidreira', 'nekhayevskiy', 'ustyuzhna', 'samarinda', 'bukoba', 'yellowknife', 'bluff', 'bambous virieux', 'srednekolymsk', 'malakal', 'skjervoy', 'toliary', 'yumen', 'santa isabel do rio negro', 'sentyabrskiy', 'kavaratti', 'amderma', 'severo-yeniseyskiy', 'along', 'zhicheng', 'ramasukha', 'kaitangata', 'jibuti', 'sal rei', 'bandarbeyla', 'lebu', 'leningradskiy', 'fortuna', 'ananas', 'noumea', 'jaranwala', 'beringovskiy', 'guozhen', 'thompson', 'umarizal', 'faya', 'haicheng', 'pitimbu', 'verkhnyaya inta', 'kastamonu', 'nikolskoye', 'castro', 'barawe', 'magan', 'manta', 'mayo', 'praya', 'pacific grove', 'buon me thuot', 'auki', 'dryden', 'buritizeiro', 'chilca', 'kroya', 'hambantota', 'vardo', 'northam', 'hithadhoo', 'rosarito', 'shadegan', 'vostok', 'matara', 'aswan', 'bam', 'gat', 'saint-augustin', 'kariba', 'san patricio', 'ilulissat', 'yirol', 'cabatuan', 'attawapiskat', 'kamenskoye', 'namatanai', 'sioux lookout', 'hailar', 'rungata', 'khatanga', 'krasnyy klyuch', 'geraldton', 'jhansi', 'holly hill', 'bethel', 'meadow lake', 'los llanos de aridane', 'elizabeth city', 'shelburne', 'grand river south east', 'flinders', 'fare', 'pavlohrad', 'cururupu', 'barentsburg', 'hobyo', 'klaksvik', 'makushino', 'cam pha', 'isangel', 'westport', 'nuuk', 'illoqqortoormiut', 'dhidhdhoo', 'atbasar', 'saleaula', 'kahului', 'puerto escondido', 'garowe', 'belushya guba', 'qaanaaq', 'airai', 'wuwei', 'angoram', 'sandviken', 'eureka', 'tuggurt', 'cervo', 'vangaindrano', 'adrar', 'ilhabela', 'gobabis', 'kontagora', 'san policarpo', 'manokwari', 'barbar', 'kendal', 'teacapan', 'arraial do cabo', 'port keats', 'pangnirtung', 'inirida', 'muros', 'hasaki', 'capiibary', 'tura', 'tazovskiy', 'ordubad', 'vila', 'phonhong', 'lavrentiya', 'qingdao', 'cockburn harbour', 'griffith', 'manado', 'phagwara', 'fairbanks', 'constitucion', 'parkes', 'yar-sale', 'sambava', 'baruun-urt', 'samusu', 'nanning', 'suhindol', 'aitape', 'cayenne', 'sumbawa', 'takhtamygda', 'prainha', 'wanning', 'alofi', 'grieskirchen', 'tiksi', 'alice springs', 'frontera', 'somerset', 'vila velha', 'torbay', 'darapidap', 'namalenga', 'nguiu', 'casper', 'beruwala', 'tabiauea', 'erenhot', 'bonavista', 'havoysund', 'conceicao do araguaia', 'cherskiy', 'aklavik', 'mutsamudu', 'roald', 'katha', 'kikwit', 'dibaya', 'lazaro cardenas', 'olafsvik', 'coos bay', 'kaeo', 'san luis', 'la gomera', 'nongan', 'dali ...

# %%
#perform API calls for a weather check for each city using a series of API calls. Include the print log of each city (city number and city name)


url = "https://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

query_url = f"{url}appid={weather_api_key}&units={units}&q="
# query_url

# %%
#60 calls per minute, check weather response
weather_response = requests.get(query_url + city).json()
weather_response
# Out:
# {'coord': {'lon': -9.38, 'lat': 39.36},
#  'weather': [{'id': 802,
#    'main': 'Clouds',
#    'description': 'scattered clouds',
#    'icon': '03d'}],
#  'base': 'stations',
#  'main': {'temp': 84.13,
#   'feels_like': 88.36,
#   'temp_min': 81,
#   'temp_max': 88,
#   'pressure': 1013,
#   'humidity': 65},
#  'visibility': 10000,
#  'wind': {'speed': 7, 'deg': 327, 'gust': 11.01},
#  'clouds': {'all': 37},
#  'dt': 1595251422,
#  'sys': {'type': 3,
#   'id': 2002825,
#   'country': 'PT',
#   'sunrise': 1595222830,
#   'sunset': 1595275215},
#  'timezone': 3600,
#  'id': 2264923,
#  'name': 'Peniche',
#  'cod': 200}

# %%
#create empty list to process city number and city name
weather_df = pd.DataFrame()
city_list = []
country = []
date = []
lat = []
lon = []
cloudiness = []
humidity = []
max_temp = []
wind_speed = []

set_value = 0


print("Beginning Data Retrieval")
print("---------------------")

#create for loop for cities in cities
for city in cities:
    
    try:
       
        weather_response = requests.get(query_url + city).json()
        lon.append(weather_response["coord"]["lon"])
        lat.append(weather_response["coord"]["lat"])
        date.append(weather_response["dt"])
        country.append(weather_response["sys"]["country"])
        cloudiness.append(weather_response["clouds"]["all"])
        humidity.append(weather_response["main"]["humidity"])
        max_temp.append(weather_response["main"]["temp_max"])
        wind_speed.append(weather_response["wind"]["speed"])
        city_list.append(city)

        #add the timer
        set_value += 1
        time.sleep(1.0)
    
        print(f"Processing Record {cities.index(city)} of set {set_value} |{city}")
        
    except (KeyError, IndexError):
        print(f"City Not Found. Skipping...{city}")
        print("------------------")
        
print("Data Retrieval Complete")
print("------------------------")
# Out:
# Beginning Data Retrieval
# ---------------------
# Processing Record 0 of set 1 |coahuayana
# Processing Record 1 of set 2 |dingle
# Processing Record 2 of set 3 |ribeira grande
# Processing Record 3 of set 4 |botwood
# Processing Record 4 of set 5 |hilo
# Processing Record 5 of set 6 |atuona
# Processing Record 6 of set 7 |rikitea
# Processing Record 7 of set 8 |ushuaia
# Processing Record 8 of set 9 |sobolevo
# Processing Record 9 of set 10 |kodiak
# Processing Record 10 of set 11 |luganville
# Processing Record 11 of set 12 |chicama
# Processing Record 12 of set 13 |punta arenas
# Processing Record 13 of set 14 |mataura
# Processing Record 14 of set 15 |busselton
# Processing Record 15 of set 16 |jalu
# Processing Record 16 of set 17 |zhigansk
# Processing Record 17 of set 18 |balagansk
# Processing Record 18 of set 19 |east london
# Processing Record 19 of set 20 |kavieng
# Processing Record 20 of set 21 |clyde river
# Processing Record 21 of set 22 |port alfred
# Processing Record 22 of set 23 |chuy
# Processing Record 23 of set 24 |hobart
# Processing Record 24 of set 25 |mocuba
# Processing Record 25 of set 26 |sao mateus do sul
# Processing Record 26 of set 27 |marquette
# Processing Record 27 of set 28 |smidovich
# Processing Record 28 of set 29 |kruisfontein
# Processing Record 29 of set 30 |salinopolis
# Processing Record 30 of set 31 |albany
# Processing Record 31 of set 32 |liusha
# Processing Record 32 of set 33 |atikokan
# Processing Record 33 of set 34 |bredasdorp
# City Not Found. Skipping...satitoa
# ------------------
# City Not Found. Skipping...tsihombe
# ------------------
# Processing Record 36 of set 35 |dikson
# Processing Record 37 of set 36 |maniwaki
# Processing Record 38 of set 37 |vaini
# Processing Record 39 of set 38 |necochea
# Processing Record 40 of set 39 |sur
# Processing Record 41 of set 40 |saint-philippe
# City Not Found. Skipping...barroualie
# ------------------
# Processing Record 43 of set 41 |barrow
# Processing Record 44 of set 42 |petropavlovsk-kamchatskiy
# Processing Record 45 of set 43 |seoul
# Processing Record 46 of set 44 |beloha
# Processing Record 47 of set 45 |whyalla
# Processing Record 48 of set 46 |butaritari
# Processing Record 49 of set 47 |buchanan
# Processing Record 50 of set 48 |kloulklubed
# Processing Record 51 of set 49 |sarangani
# Processing Record 52 of set 50 |jamestown
# Processing Record 53 of set 51 |pisco
# Processing Record 54 of set 52 |kerman
# Processing Record 55 of set 53 |hovd
# Processing Record 56 of set 54 |tuktoyaktuk
# Processing Record 57 of set 55 |touros
# Processing Record 58 of set 56 |nanortalik
# Processing Record 59 of set 57 |carndonagh
# Processing Record 60 of set 58 |maneadero
# Processing Record 61 of set 59 |severo-kurilsk
# Processing Record 62 of set 60 |puerto ayora
# Processing Record 63 of set 61 |kapaa
# Processing Record 64 of set 62 |port blair
# Processing Record 65 of set 63 |vila franca do campo
# Processing Record 66 of set 64 |narsaq
# Processing Record 67 of set 65 |lamballe
# Processing Record 68 of set 66 |victoria
# Processing Record 69 of set 67 |port elizabeth
# Processing Record 70 of set 68 |inhambane
# Processing Record 71 of set 69 |cabo san lucas
# Processing Record 72 of set 70 |loksa
# Processing Record 73 of set 71 |belaya gora
# Processing Record 74 of set 72 |port hardy
# Processing Record 75 of set 73 |zemio
# Processing Record 76 of set 74 |avera
# Processing Record 77 of set 75 |college
# Processing Record 78 of set 76 |halden
# Processing Record 79 of set 77 |new norfolk
# City Not Found. Skipping...sataua
# ------------------
# Processing Record 81 of set 78 |jeremie
# Processing Record 82 of set 79 |bulgan
# Processing Record 83 of set 80 |bilma
# Processing Record 84 of set 81 |quatre cocos
# Processing Record 85 of set 82 |voh
# Processing Record 86 of set 83 |brae
# Processing Record 87 of set 84 |grindavik
# Processing Record 88 of set 85 |mahebourg
# City Not Found. Skipping...nizhneyansk
# ------------------
# Processing Record 90 of set 86 |provideniya
# City Not Found. Skipping...meyungs
# ------------------
# Processing Record 92 of set 87 |slave lake
# Processing Record 93 of set 88 |sri aman
# Processing Record 94 of set 89 |saint george
# Processing Record 95 of set 90 |anadyr
# Processing Record 96 of set 91 |prince albert
# Processing Record 97 of set 92 |cochrane
# Processing Record 98 of set 93 |ponta do sol
# Processing Record 99 of set 94 |tiarei
# Processing Record 100 of set 95 |te anau
# Processing Record 101 of set 96 |mar del plata
# Processing Record 102 of set 97 |san cristobal
# Processing Record 103 of set 98 |hamilton
# Processing Record 104 of set 99 |hermanus
# Processing Record 105 of set 100 |mount gambier
# Processing Record 106 of set 101 |ovalle
# Processing Record 107 of set 102 |manicore
# Processing Record 108 of set 103 |jiangyou
# Processing Record 109 of set 104 |cape town
# Processing Record 110 of set 105 |mount isa
# Processing Record 111 of set 106 |sao filipe
# Processing Record 112 of set 107 |akureyri
# Processing Record 113 of set 108 |port hedland
# Processing Record 114 of set 109 |carnarvon
# Processing Record 115 of set 110 |palana
# Processing Record 116 of set 111 |longyearbyen
# Processing Record 117 of set 112 |faanui
# Processing Record 118 of set 113 |bathsheba
# Processing Record 119 of set 114 |avarua
# Processing Record 120 of set 115 |lima
# City Not Found. Skipping...taolanaro
# ------------------
# Processing Record 122 of set 116 |georgetown
# Processing Record 123 of set 117 |saskylakh
# Processing Record 124 of set 118 |krasnoselkup
# Processing Record 125 of set 119 |gwadar
# Processing Record 126 of set 120 |ancud
# Processing Record 127 of set 121 |lumby
# Processing Record 128 of set 122 |panlaitan
# Processing Record 129 of set 123 |cidreira
# Processing Record 130 of set 124 |nekhayevskiy
# Processing Record 131 of set 125 |ustyuzhna
# Processing Record 132 of set 126 |samarinda
# Processing Record 133 of set 127 |bukoba
# Processing Record 134 of set 128 |yellowknife
# Processing Record 135 of set 129 |bluff
# Processing Record 136 of set 130 |bambous virieux
# Processing Record 137 of set 131 |srednekolymsk
# Processing Record 138 of set 132 |malakal
# Processing Record 139 of set 133 |skjervoy
# City Not Found. Skipping...toliary
# ------------------
# Processing Record 141 of set 134 |yumen
# Processing Record 142 of set 135 |santa isabel do rio negro
# City Not Found. Skipping...sentyabrskiy
# ------------------
# Processing Record 144 of set 136 |kavaratti
# City Not Found. Skipping...amderma
# ------------------
# Processing Record 146 of set 137 |severo-yeniseyskiy
# Processing Record 147 of set 138 |along
# Processing Record 148 of set 139 |zhicheng
# City Not Found. Skipping...ramasukha
# ------------------
# Processing Record 150 of set 140 |kaitangata
# Processing Record 151 of set 141 |jibuti
# Processing Record 152 of set 142 |sal rei
# Processing Record 153 of set 143 |bandarbeyla
# Processing Record 154 of set 144 |lebu
# Processing Record 155 of set 145 |leningradskiy
# Processing Record 156 of set 146 |fortuna
# Processing Record 157 of set 147 |ananas
# Processing Record 158 of set 148 |noumea
# Processing Record 159 of set 149 |jaranwala
# Processing Record 160 of set 150 |beringovskiy
# Processing Record 161 of set 151 |guozhen
# Processing Record 162 of set 152 |thompson
# Processing Record 163 of set 153 |umarizal
# Processing Record 164 of set 154 |faya
# Processing Record 165 of set 155 |haicheng
# Processing Record 166 of set 156 |pitimbu
# Processing Record 167 of set 157 |verkhnyaya inta
# Processing Record 168 of set 158 |kastamonu
# Processing Record 169 of set 159 |nikolskoye
# Processing Record 170 of set 160 |castro
# City Not Found. Skipping...barawe
# ------------------
# Processing Record 172 of set 161 |magan
# Processing Record 173 of set 162 |manta
# Processing Record 174 of set 163 |mayo
# Processing Record 175 of set 164 |praya
# Processing Record 176 of set 165 |pacific grove
# City Not Found. Skipping...buon me thuot
# ------------------
# Processing Record 178 of set 166 |auki
# Processing Record 179 of set 167 |dryden
# Processing Record 180 of set 168 |buritizeiro
# Processing Record 181 of set 169 |chilca
# Processing Record 182 of set 170 |kroya
# Processing Record 183 of set 171 |hambantota
# Processing Record 184 of set 172 |vardo
# Processing Record 185 of set 173 |northam
# Processing Record 186 of set 174 |hithadhoo
# Processing Record 187 of set 175 |rosarito
# Processing Record 188 of set 176 |shadegan
# Processing Record 189 of set 177 |vostok
# Processing Record 190 of set 178 |matara
# Processing Record 191 of set 179 |aswan
# Processing Record 192 of set 180 |bam
# Processing Record 193 of set 181 |gat
# Processing Record 194 of set 182 |saint-augustin
# Processing Record 195 of set 183 |kariba
# Processing Record 196 of set 184 |san patricio
# Processing Record 197 of set 185 |ilulissat
# City Not Found. Skipping...yirol
# ------------------
# Processing Record 199 of set 186 |cabatuan
# City Not Found. Skipping...attawapiskat
# ------------------
# City Not Found. Skipping...kamenskoye
# ------------------
# Processing Record 202 of set 187 |namatanai
# Processing Record 203 of set 188 |sioux lookout
# Processing Record 204 of set 189 |hailar
# City Not Found. Skipping...rungata
# ------------------
# Processing Record 206 of set 190 |khatanga
# Processing Record 207 of set 191 |krasnyy klyuch
# Processing Record 208 of set 192 |geraldton
# Processing Record 209 of set 193 |jhansi
# Processing Record 210 of set 194 |holly hill
# Processing Record 211 of set 195 |bethel
# Processing Record 212 of set 196 |meadow lake
# Processing Record 213 of set 197 |los llanos de aridane
# Processing Record 214 of set 198 |elizabeth city
# Processing Record 215 of set 199 |shelburne
# City Not Found. Skipping...grand river south east
# ------------------
# Processing Record 217 of set 200 |flinders
# Processing Record 218 of set 201 |fare
# Processing Record 219 of set 202 |pavlohrad
# Processing Record 220 of set 203 |cururupu
# City Not Found. Skipping...barentsburg
# ------------------
# Processing Record 222 of set 204 |hobyo
# Processing Record 223 of set 205 |klaksvik
# Processing Record 224 of set 206 |makushino
# City Not Found. Skipping...cam pha
# ------------------
# Processing Record 226 of set 207 |isangel
# Processing Record 227 of set 208 |westport
# Processing Record 228 of set 209 |nuuk
# City Not Found. Skipping...illoqqortoormiut
# ------------------
# Processing Record 230 of set 210 |dhidhdhoo
# Processing Record 231 of set 211 |atbasar
# City Not Found. Skipping...saleaula
# ------------------
# Processing Record 233 of set 212 |kahului
# Processing Record 234 of set 213 |puerto escondido
# Processing Record 235 of set 214 |garowe
# City Not Found. Skipping...belushya guba
# ------------------
# Processing Record 237 of set 215 |qaanaaq
# Processing Record 238 of set 216 |airai
# Processing Record 239 of set 217 |wuwei
# Processing Record 240 of set 218 |angoram
# Processing Record 241 of set 219 |sandviken
# Processing Record 242 of set 220 |eureka
# City Not Found. Skipping...tuggurt
# ------------------
# Processing Record 244 of set 221 |cervo
# Processing Record 245 of set 222 |vangaindrano
# Processing Record 246 of set 223 |adrar
# Processing Record 247 of set 224 |ilhabela
# Processing Record 248 of set 225 |gobabis
# Processing Record 249 of set 226 |kontagora
# Processing Record 250 of set 227 |san policarpo
# Processing Record 251 of set 228 |manokwari
# City Not Found. Skipping...barbar
# ------------------
# Processing Record 253 of set 229 |kendal
# Processing Record 254 of set 230 |teacapan
# Processing Record 255 of set 231 |arraial do cabo
# Processing Record 256 of set 232 |port keats
# Processing Record 257 of set 233 |pangnirtung
# Processing Record 258 of set 234 |inirida
# Processing Record 259 of set 235 |muros
# Processing Record 260 of set 236 |hasaki
# Processing Record 261 of set 237 |capiibary
# Processing Record 262 of set 238 |tura
# Processing Record 263 of set 239 |tazovskiy
# Processing Record 264 of set 240 |ordubad
# Processing Record 265 of set 241 |vila
# Processing Record 266 of set 242 |phonhong
# Processing Record 267 of set 243 |lavrentiya
# Processing Record 268 of set 244 |qingdao
# City Not Found. Skipping...cockburn harbour
# ------------------
# Processing Record 270 of set 245 |griffith
# Processing Record 271 of set 246 |manado
# Processing Record 272 of set 247 |phagwara
# Processing Record 273 of set 248 |fairbanks
# Processing Record 274 of set 249 |constitucion
# Processing Record 275 of set 250 |parkes
# Processing Record 276 of set 251 |yar-sale
# Processing Record 277 of set 252 |sambava
# Processing Record 278 of set 253 |baruun-urt
# City Not Found. Skipping...samusu
# ------------------
# Processing Record 280 of set 254 |nanning
# Processing Record 281 of set 255 |suhindol
# Processing Record 282 of set 256 |aitape
# Processing Record 283 of set 257 |cayenne
# City Not Found. Skipping...sumbawa
# ------------------
# Processing Record 285 of set 258 |takhtamygda
# Processing Record 286 of set 259 |prainha
# Processing Record 287 of set 260 |wanning
# Processing Record 288 of set 261 |alofi
# Processing Record 289 of set 262 |grieskirchen
# Processing Record 290 of set 263 |tiksi
# Processing Record 291 of set 264 |alice springs
# Processing Record 292 of set 265 |frontera
# Processing Record 293 of set 266 |somerset
# Processing Record 294 of set 267 |vila velha
# Processing Record 295 of set 268 |torbay
# Processing Record 296 of set 269 |darapidap
# Processing Record 297 of set 270 |namalenga
# City Not Found. Skipping...nguiu
# ------------------
# Processing Record 299 of set 271 |casper
# Processing Record 300 of set 272 |beruwala
# City Not Found. Skipping...tabiauea
# ------------------
# Processing Record 302 of set 273 |erenhot
# Processing Record 303 of set 274 |bonavista
# Processing Record 304 of set 275 |havoysund
# Processing Record 305 of set 276 |conceicao do araguaia
# Processing Record 306 of set 277 |cherskiy
# Processing Record 307 of set 278 |aklavik
# City Not Found. Skipping...mutsamudu
# ------------------
# Processing Record 309 of set 279 |roald
# City Not Found. Skipping...katha
# ------------------
# Processing Record 311 of set 280 |kikwit
# City Not Found. Skipping...dibaya
# ------------------
# Processing Record 313 of set 281 |lazaro cardenas
# Processing Record 314 of set 282 |olafsvik
# Processing Record 315 of set 283 |coos bay
# Processing Record 316 of set 284 |kaeo
# Processing Record 317 of set 285 |san luis
# Processing Record 318 of set 286 |la gomera
# Processing Record 319 of set 287 |nongan
# Processing Record 320 of set 288 |dali
# Processing Record 321 of set 289 |walvis bay
# Processing Record 322 of set 290 |nagorsk
# Processing Record 323 of set 291 |bobo dioulasso
# Processing Record 324 of set 292 |sarab
# Processing Record 325 of set 293 |zlobin
# Processing Record 326 of set 294 |sitka
# Processing Record 327 of set 295 |presidencia roque saenz pena
# Processing Record 328 of set 296 |lixourion
# City Not Found. Skipping...bargal
# ------------------
# Processing Record 330 of set 297 |klichka
# Processing Record 331 of set 298 |portland
# Processing Record 332 of set 299 |nishihara
# Processing Record 333 of set 300 |surgut
# Processing Record 334 of set 301 |hokitika
# Processing Record 335 of set 302 |lompoc
# Processing Record 336 of set 303 |ridgecrest
# Processing Record 337 of set 304 |lagoa
# Processing Record 338 of set 305 |talnakh
# Processing Record 339 of set 306 |changping
# Processing Record 340 of set 307 |deniliquin
# Processing Record 341 of set 308 |aasiaat
# Processing Record 342 of set 309 |kindia
# Processing Record 343 of set 310 |stornoway
# City Not Found. Skipping...bolshaya orlovka
# ------------------
# Processing Record 345 of set 311 |coquimbo
# Processing Record 346 of set 312 |cheney
# City Not Found. Skipping...sinkat
# ------------------
# Processing Record 348 of set 313 |bairiki
# Processing Record 349 of set 314 |logansport
# Processing Record 350 of set 315 |znamenka
# City Not Found. Skipping...umzimvubu
# ------------------
# Processing Record 352 of set 316 |labuhan
# Processing Record 353 of set 317 |visnes
# Processing Record 354 of set 318 |manadhoo
# Processing Record 355 of set 319 |thinadhoo
# Processing Record 356 of set 320 |korla
# City Not Found. Skipping...khonuu
# ------------------
# Processing Record 358 of set 321 |whitehorse
# Processing Record 359 of set 322 |xining
# Processing Record 360 of set 323 |tupaciguara
# Processing Record 361 of set 324 |rapid valley
# Processing Record 362 of set 325 |san quintin
# Processing Record 363 of set 326 |pleasanton
# Processing Record 364 of set 327 |esperance
# Processing Record 365 of set 328 |aksu
# Processing Record 366 of set 329 |tasiilaq
# Processing Record 367 of set 330 |lillooet
# Processing Record 368 of set 331 |trofors
# Processing Record 369 of set 332 |thessalon
# Processing Record 370 of set 333 |alenquer
# Processing Record 371 of set 334 |morant bay
# Processing Record 372 of set 335 |saldanha
# Processing Record 373 of set 336 |priargunsk
# Processing Record 374 of set 337 |novaya igirma
# Processing Record 375 of set 338 |katsuura
# Processing Record 376 of set 339 |prince rupert
# Processing Record 377 of set 340 |shakawe
# Processing Record 378 of set 341 |bagdarin
# Processing Record 379 of set 342 |hay river
# Processing Record 380 of set 343 |guerrero negro
# Processing Record 381 of set 344 |upernavik
# Processing Record 382 of set 345 |broome
# Processing Record 383 of set 346 |buriti dos lopes
# Processing Record 384 of set 347 |nara
# Processing Record 385 of set 348 |lorengau
# Processing Record 386 of set 349 |port-cartier
# Processing Record 387 of set 350 |luderitz
# Processing Record 388 of set 351 |qaqortoq
# Processing Record 389 of set 352 |salinas
# Processing Record 390 of set 353 |rybinsk
# City Not Found. Skipping...palabuhanratu
# ------------------
# Processing Record 392 of set 354 |chokurdakh
# Processing Record 393 of set 355 |aksarka
# Processing Record 394 of set 356 |ghanzi
# Processing Record 395 of set 357 |manggar
# Processing Record 396 of set 358 |locri
# Processing Record 397 of set 359 |axim
# Processing Record 398 of set 360 |oum hadjer
# Processing Record 399 of set 361 |saint-francois
# Processing Record 400 of set 362 |marawi
# Processing Record 401 of set 363 |jimeta
# Processing Record 402 of set 364 |jacupiranga
# Processing Record 403 of set 365 |kununurra
# Processing Record 404 of set 366 |dalbandin
# Processing Record 405 of set 367 |opuwo
# Processing Record 406 of set 368 |komsomolskiy
# Processing Record 407 of set 369 |klyuchi
# Processing Record 408 of set 370 |bambanglipuro
# Processing Record 409 of set 371 |channel-port aux basques
# Processing Record 410 of set 372 |jining
# Processing Record 411 of set 373 |bengkulu
# City Not Found. Skipping...manzil jamil
# ------------------
# City Not Found. Skipping...wulanhaote
# ------------------
# Processing Record 414 of set 374 |palmer
# Processing Record 415 of set 375 |vanimo
# Processing Record 416 of set 376 |oriximina
# Processing Record 417 of set 377 |ulladulla
# Processing Record 418 of set 378 |ngunguru
# Processing Record 419 of set 379 |mungwi
# Processing Record 420 of set 380 |hualmay
# Processing Record 421 of set 381 |ko samui
# Processing Record 422 of set 382 |hofn
# Processing Record 423 of set 383 |pevek
# Processing Record 424 of set 384 |livingston
# Processing Record 425 of set 385 |san pedro
# Processing Record 426 of set 386 |ostrovnoy
# Processing Record 427 of set 387 |chazuta
# Processing Record 428 of set 388 |gambo
# Processing Record 429 of set 389 |artvin
# Processing Record 430 of set 390 |shache
# Processing Record 431 of set 391 |margate
# Processing Record 432 of set 392 |morgan city
# Processing Record 433 of set 393 |caluquembe
# Processing Record 434 of set 394 |suciu de sus
# Processing Record 435 of set 395 |karratha
# Processing Record 436 of set 396 |tocopilla
# Processing Record 437 of set 397 |najran
# Processing Record 438 of set 398 |xuddur
# Processing Record 439 of set 399 |ziyang
# Processing Record 440 of set 400 |dwarka
# City Not Found. Skipping...mys shmidta
# ------------------
# Processing Record 442 of set 401 |kenora
# Processing Record 443 of set 402 |souillac
# Processing Record 444 of set 403 |tougue
# Processing Record 445 of set 404 |ames
# Processing Record 446 of set 405 |antofagasta
# Processing Record 447 of set 406 |coffeyville
# Processing Record 448 of set 407 |shimsk
# Processing Record 449 of set 408 |rawson
# Processing Record 450 of set 409 |kuytun
# Processing Record 451 of set 410 |brigantine
# Processing Record 452 of set 411 |rio gallegos
# Processing Record 453 of set 412 |pierre
# City Not Found. Skipping...burica
# ------------------
# Processing Record 455 of set 413 |werda
# Processing Record 456 of set 414 |general pico
# Processing Record 457 of set 415 |tommot
# Processing Record 458 of set 416 |juba
# Processing Record 459 of set 417 |kyshtovka
# Processing Record 460 of set 418 |derzhavinsk
# Processing Record 461 of set 419 |saint anthony
# Processing Record 462 of set 420 |yomou
# Processing Record 463 of set 421 |syracuse
# Processing Record 464 of set 422 |teknaf
# Processing Record 465 of set 423 |aquiraz
# Processing Record 466 of set 424 |praia da vitoria
# Processing Record 467 of set 425 |ahipara
# Processing Record 468 of set 426 |anloga
# Processing Record 469 of set 427 |kibre mengist
# Processing Record 470 of set 428 |katwa
# Processing Record 471 of set 429 |norman wells
# Processing Record 472 of set 430 |zambezi
# City Not Found. Skipping...ituni
# ------------------
# Processing Record 474 of set 431 |eyl
# Processing Record 475 of set 432 |ambulu
# Processing Record 476 of set 433 |verkhnevilyuysk
# Processing Record 477 of set 434 |poum
# Processing Record 478 of set 435 |beroroha
# Processing Record 479 of set 436 |ust-nera
# Processing Record 480 of set 437 |lasa
# Processing Record 481 of set 438 |verkhnebakanskiy
# Processing Record 482 of set 439 |acapulco
# Processing Record 483 of set 440 |benjamin aceval
# Processing Record 484 of set 441 |nelson bay
# Processing Record 485 of set 442 |gizo
# Processing Record 486 of set 443 |kawhia
# Processing Record 487 of set 444 |camargo
# City Not Found. Skipping...vaitupu
# ------------------
# Processing Record 489 of set 445 |miles city
# Processing Record 490 of set 446 |san carlos de bariloche
# Processing Record 491 of set 447 |bonao
# Processing Record 492 of set 448 |tirumullaivasal
# Processing Record 493 of set 449 |mont-saint-aignan
# Processing Record 494 of set 450 |lamu
# Processing Record 495 of set 451 |mabaruma
# Processing Record 496 of set 452 |fukue
# Processing Record 497 of set 453 |cabuyaro
# Processing Record 498 of set 454 |russell
# Processing Record 499 of set 455 |okato
# Processing Record 500 of set 456 |kota kinabalu
# Processing Record 501 of set 457 |vao
# Processing Record 502 of set 458 |santarem
# Processing Record 503 of set 459 |comodoro rivadavia
# Processing Record 504 of set 460 |atar
# Processing Record 505 of set 461 |tessalit
# Processing Record 506 of set 462 |kitale
# Processing Record 507 of set 463 |nyimba
# Processing Record 508 of set 464 |hami
# Processing Record 509 of set 465 |ferme-neuve
# Processing Record 510 of set 466 |sibolga
# Processing Record 511 of set 467 |laguna
# Processing Record 512 of set 468 |arrecife
# Processing Record 513 of set 469 |xixiang
# Processing Record 514 of set 470 |taltal
# Processing Record 515 of set 471 |roebourne
# Processing Record 516 of set 472 |tabou
# Processing Record 517 of set 473 |kanigiri
# Processing Record 518 of set 474 |rancho palos verdes
# City Not Found. Skipping...mendahara
# ------------------
# Processing Record 520 of set 475 |zonguldak
# Processing Record 521 of set 476 |henties bay
# Processing Record 522 of set 477 |maltahohe
# Processing Record 523 of set 478 |san miguel
# Processing Record 524 of set 479 |wakkanai
# Processing Record 525 of set 480 |boyolangu
# Processing Record 526 of set 481 |klin
# Processing Record 527 of set 482 |minggang
# Processing Record 528 of set 483 |port augusta
# Processing Record 529 of set 484 |glushkovo
# Processing Record 530 of set 485 |saiha
# Processing Record 531 of set 486 |lata
# Processing Record 532 of set 487 |ritchie
# Processing Record 533 of set 488 |koslan
# Processing Record 534 of set 489 |denpasar
# Processing Record 535 of set 490 |sulangan
# City Not Found. Skipping...falealupo
# ------------------
# Processing Record 537 of set 491 |puri
# Processing Record 538 of set 492 |diffa
# City Not Found. Skipping...thano bula khan
# ------------------
# Processing Record 540 of set 493 |siocon
# Processing Record 541 of set 494 |mezen
# Processing Record 542 of set 495 |yarada
# Processing Record 543 of set 496 |jacareacanga
# Processing Record 544 of set 497 |shimoda
# Processing Record 545 of set 498 |moerai
# City Not Found. Skipping...mullaitivu
# ------------------
# Processing Record 547 of set 499 |rio grande
# Processing Record 548 of set 500 |altay
# Processing Record 549 of set 501 |kismayo
# Processing Record 550 of set 502 |nouadhibou
# City Not Found. Skipping...inderborskiy
# ------------------
# Processing Record 552 of set 503 |kutum
# Processing Record 553 of set 504 |biskamzha
# Processing Record 554 of set 505 |den helder
# Processing Record 555 of set 506 |leo
# Processing Record 556 of set 507 |ongandjera
# Processing Record 557 of set 508 |quelimane
# Processing Record 558 of set 509 |tual
# Processing Record 559 of set 510 |arlit
# Processing Record 560 of set 511 |tarakan
# Processing Record 561 of set 512 |sale
# Processing Record 562 of set 513 |galesong
# Processing Record 563 of set 514 |alekseyevskaya
# Processing Record 564 of set 515 |rosa zarate
# Processing Record 565 of set 516 |alakurtti
# Processing Record 566 of set 517 |coihaique
# Processing Record 567 of set 518 |batagay
# Processing Record 568 of set 519 |wilmington
# Processing Record 569 of set 520 |okhotsk
# Processing Record 570 of set 521 |kelvington
# Processing Record 571 of set 522 |khambhat
# Processing Record 572 of set 523 |streator
# Processing Record 573 of set 524 |otukpo
# Processing Record 574 of set 525 |doha
# City Not Found. Skipping...tumannyy
# ------------------
# Processing Record 576 of set 526 |namibe
# Processing Record 577 of set 527 |caravelas
# Processing Record 578 of set 528 |naze
# Processing Record 579 of set 529 |sorland
# Processing Record 580 of set 530 |kiunga
# City Not Found. Skipping...rostaq
# ------------------
# Processing Record 582 of set 531 |bintulu
# Processing Record 583 of set 532 |wajid
# Processing Record 584 of set 533 |babati
# Processing Record 585 of set 534 |camacha
# Processing Record 586 of set 535 |pingliang
# Processing Record 587 of set 536 |orange cove
# Processing Record 588 of set 537 |bonthe
# Processing Record 589 of set 538 |dunedin
# Processing Record 590 of set 539 |nongstoin
# Processing Record 591 of set 540 |iqaluit
# Processing Record 592 of set 541 |zaozerne
# Processing Record 593 of set 542 |joutseno
# Processing Record 594 of set 543 |kieta
# Processing Record 595 of set 544 |santiago del estero
# Processing Record 596 of set 545 |pochutla
# Processing Record 597 of set 546 |kirando
# Processing Record 598 of set 547 |valle de allende
# Processing Record 599 of set 548 |wanaka
# Processing Record 600 of set 549 |kijang
# Processing Record 601 of set 550 |cockburn town
# Processing Record 602 of set 551 |christchurch
# Processing Record 603 of set 552 |bustamante
# Processing Record 604 of set 553 |aksay
# Processing Record 605 of set 554 |pahrump
# Processing Record 606 of set 555 |pangai
# Processing Record 607 of set 556 |misratah
# Processing Record 608 of set 557 |tandlianwala
# Processing Record 609 of set 558 |havre-saint-pierre
# Processing Record 610 of set 559 |peniche
# Data Retrieval Complete
# ------------------------

# %%
#convert raw data to dataframe do this by creating a dictionary 

weather_dict = {
    "City": city_list,
    "Country": country,
    "Lat": lat,
    "Lon": lon,
    "Max Temp": max_temp,
    "Humidity": humidity,
    "Date": date,
    "Clouds": cloudiness,
    "Wind Speed": wind_speed
}
weather_df = pd.DataFrame(weather_dict)
weather_df
# Out:
#                    City Country    Lat     Lon  Max Temp  Humidity  \
# 0            coahuayana      MX  18.73 -103.68     71.60        78
# 1                dingle      PH  11.00  122.67     78.69        80
# 2        ribeira grande      PT  38.52  -28.70     73.40        60
# 3               botwood      CA  49.15  -55.35     75.20        50
# 4                  hilo      US  19.73 -155.09     75.20        78
# ..                  ...     ...    ...     ...       ...       ...
# 554              pangai      TO -19.80 -174.35     73.40        88
# 555            misratah      LY  32.38   15.09     81.52        58
# 556        tandlianwala      PK  31.03   73.13     92.98        53
# 557  havre-saint-pierre      CA  50.23  -63.60     66.20       100
# 558             peniche      PT  39.36   -9.38     88.00        67
#
#            Date  Clouds  Wind Speed
# 0    1595251434       5        9.17
# 1    1595251435      11        5.26
# 2    1595251420      75        6.93
# 3    1595251437      20        6.93
# 4    1595251142      90        5.82
# ..          ...     ...         ...
# 554  1595252183      75        5.82
# 555  1595252184       0       12.66
# 556  1595252185      31       21.41
# 557  1595252187      90        5.82
# 558  1595252188      35        8.01
#
# [559 rows x 9 columns]

# %%
#count to ensure all cities are in dataframe

weather_df.count()
# Out:
# City          559
# Country       559
# Lat           559
# Lon           559
# Max Temp      559
# Humidity      559
# Date          559
# Clouds        559
# Wind Speed    559
# dtype: int64

# %%
#export to a csv
weather_df.to_csv("output_data/weatherPy_data.csv", encoding="utf-8", index=False)

# %%
#Check for cities with humidity
weather_df.describe()
# Out:
#               Lat         Lon    Max Temp    Humidity          Date  \
# count  559.000000  559.000000  559.000000  559.000000  5.590000e+02
# mean    19.397335   17.518569   71.369946   68.395349  1.595252e+09
# std     33.070141   91.960726   14.372281   22.733363  3.560541e+02
# min    -54.800000 -175.200000   21.200000    3.000000  1.595251e+09
# 25%     -6.725000  -66.025000   61.125000   56.000000  1.595251e+09
# 50%     22.550000   21.850000   74.530000   74.000000  1.595252e+09
# 75%     46.980000  102.345000   80.600000   85.000000  1.595252e+09
# max     78.220000  179.320000  122.000000  100.000000  1.595252e+09
#
#            Clouds  Wind Speed
# count  559.000000  559.000000
# mean    50.817531    7.880429
# std     38.541915    5.267627
# min      0.000000    0.110000
# 25%     11.000000    3.980000
# 50%     51.000000    6.930000
# 75%     90.000000   10.290000
# max    100.000000   31.230000

# %%
#indices of cities that have 100% humidity
humidity = weather_df['Humidity'] >= 100
humidity.value_counts()
# Out:
# False    533
# True      26
# Name: Humidity, dtype: int64

# %%
#cities with humidity
cities_humi = weather_df.loc[weather_df['Humidity'] >= 100, :]
cities_humi
# Out:
#                           City Country    Lat     Lon  Max Temp  Humidity  \
# 20                 clyde river      CA  70.47  -68.59     41.00       100
# 31                      liusha      CN  27.21  108.59     65.23       100
# 41   petropavlovsk-kamchatskiy      RU  53.05  158.65     53.60       100
# 44                     whyalla      AU -33.03  137.58     48.20       100
# 71                  port hardy      CA  50.70 -127.42     48.20       100
# 90               prince albert      CA  53.20 -105.77     55.40       100
# 95               mar del plata      AR -38.00  -57.56     53.01       100
# 99               mount gambier      AU -37.83  140.77     42.80       100
# 119                      ancud      CL -41.87  -73.82     48.00       100
# 127                yellowknife      CA  62.46 -114.35     57.20       100
# 145                    fortuna      US  40.60 -124.16     54.00       100
# 215                      airai      TL  -8.93  125.41     56.62       100
# 219                     eureka      US  40.80 -124.16     53.01       100
# 228                     kendal      GB  54.33   -2.75     62.01       100
# 241                   phonhong      LA  18.50  102.42     75.20       100
# 260                      alofi      NU -19.06 -169.92     75.20       100
# 282                   coos bay      US  43.37 -124.22     55.99       100
# 341                  hay river      CA  60.82 -115.80     55.40       100
# 348               port-cartier      CA  50.03  -66.87     68.00       100
# 386                    chazuta      PE  -6.57  -76.14     69.80       100
# 428               norman wells      CA  65.28 -126.83     53.60       100
# 482               port augusta      AU -32.50  137.77     48.20       100
# 516                  coihaique      CL -45.58  -72.07     33.80       100
# 538                  nongstoin      IN  25.52   91.27     65.23       100
# 539                    iqaluit      CA  63.75  -68.51     42.80       100
# 557         havre-saint-pierre      CA  50.23  -63.60     66.20       100
#
#            Date  Clouds  Wind Speed
# 20   1595251193      90        8.05
# 31   1595251472     100        1.57
# 41   1595251285      75        3.74
# 44   1595251489      75        8.05
# 71   1595251434      40        5.82
# 90   1595251248      90        2.24
# 95   1595250907      90       13.87
# 99   1595251557      90        5.82
# 119  1595251083      90        2.24
# 127  1595250927      40        3.36
# 145  1595251170      90        3.36
# 215  1595251171      42        2.80
# 219  1595251631      65        3.00
# 228  1595251723      77       13.00
# 241  1595251739      90        4.70
# 260  1595251337      75        6.93
# 282  1595251547      90        3.36
# 341  1595251872      40        3.36
# 348  1595251881      90        6.93
# 386  1595251930      40        2.24
# 428  1595252017      75        2.24
# 482  1595252088      75        8.05
# 516  1595252134      90        3.36
# 538  1595252162     100        2.13
# 539  1595252163      90        3.36
# 557  1595252187      90        5.82

# %%
#count to make sure cities with humidity is accurate
cities_humi.count()
# Out:
# City          26
# Country       26
# Lat           26
# Lon           26
# Max Temp      26
# Humidity      26
# Date          26
# Clouds        26
# Wind Speed    26
# dtype: int64

# %%
#create clean data dataframe for cities with under 100 humidity
clean_data = weather_df.loc[weather_df['Humidity'] < 100, :]
clean_data
# Out:
#                City Country    Lat     Lon  Max Temp  Humidity        Date  \
# 0        coahuayana      MX  18.73 -103.68     71.60        78  1595251434
# 1            dingle      PH  11.00  122.67     78.69        80  1595251435
# 2    ribeira grande      PT  38.52  -28.70     73.40        60  1595251420
# 3           botwood      CA  49.15  -55.35     75.20        50  1595251437
# 4              hilo      US  19.73 -155.09     75.20        78  1595251142
# ..              ...     ...    ...     ...       ...       ...         ...
# 553         pahrump      US  36.21 -115.98     80.01        26  1595252024
# 554          pangai      TO -19.80 -174.35     73.40        88  1595252183
# 555        misratah      LY  32.38   15.09     81.52        58  1595252184
# 556    tandlianwala      PK  31.03   73.13     92.98        53  1595252185
# 558         peniche      PT  39.36   -9.38     88.00        67  1595252188
#
#      Clouds  Wind Speed
# 0         5        9.17
# 1        11        5.26
# 2        75        6.93
# 3        20        6.93
# 4        90        5.82
# ..      ...         ...
# 553      35        4.00
# 554      75        5.82
# 555       0       12.66
# 556      31       21.41
# 558      35        8.01
#
# [533 rows x 9 columns]

# %%
#count cities without humidity
clean_data.count()
# Out:
# City          533
# Country       533
# Lat           533
# Lon           533
# Max Temp      533
# Humidity      533
# Date          533
# Clouds        533
# Wind Speed    533
# dtype: int64

# %%
#export new clean data csv

clean_data.to_csv("output_data/weatherPy_clean_data.csv", encoding="utf-8", index=False)

# %%
#create scatter plots for lat vs temp, humidity, cloudiness, windspeed
#Lat vs. temp plot

x_values = clean_data['Lat']
y_values = clean_data['Max Temp']

plt.scatter(x_values, y_values)
plt.title('Maximum Temperature Vs. Latitude')
plt.xlabel('Latitude')
plt.ylabel('Maximum Temperature')
plt.grid()

plt.savefig("output_data/tempVlatinworld.png")
plt.show()

# %% [markdown]
# Data Analysis

# %%
#lat vs. humidity plot

x_values = clean_data['Lat']
y_values = clean_data['Humidity']

plt.scatter(x_values, y_values, color="red", alpha=0.5)
plt.title('Humidity Vs. Latitude')
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.grid()

plt.savefig("output_data/humidVlatinworld.png")
plt.show()

# %% [markdown]
# Data Analysis

# %%
#lat vs. cloudiness plot

x_values = clean_data['Lat']
y_values = clean_data['Clouds']

plt.scatter(x_values, y_values)
plt.title('Cloudiness Vs. Latitude')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.grid

plt.savefig("output_data/cloudVlatinworld.png")
plt.show()

# %% [markdown]
# Data Analysis

# %%
#lat vs. wind speed plot

x_values = weather_df['Lat']
y_values = weather_df['Wind Speed']

plt.scatter(x_values, y_values, color="red", alpha=0.5)
plt.title('Wind Speed Vs. Latitude')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.grid()

plt.savefig("output_data/windspVlatinworld.png")
plt.show()

# %% [markdown]
# Data Analysis

# %%
#create dataframes for southern/norther hemispheres
#use latitude, use loc, greater or equal to 0 nothern, less than southern part
isNorth = clean_data['Lat'] >= 0# mask or filter 
isNorth.value_counts()
# Out:
# True     366
# False    167
# Name: Lat, dtype: int64

# %%
#northern hemisphere dataframe
northern_hem = clean_data.loc[isNorth, :]
northern_hem
# Out:
#                City Country    Lat     Lon  Max Temp  Humidity        Date  \
# 0        coahuayana      MX  18.73 -103.68     71.60        78  1595251434
# 1            dingle      PH  11.00  122.67     78.69        80  1595251435
# 2    ribeira grande      PT  38.52  -28.70     73.40        60  1595251420
# 3           botwood      CA  49.15  -55.35     75.20        50  1595251437
# 4              hilo      US  19.73 -155.09     75.20        78  1595251142
# ..              ...     ...    ...     ...       ...       ...         ...
# 552           aksay      RU  47.26   39.87     84.20        39  1595252180
# 553         pahrump      US  36.21 -115.98     80.01        26  1595252024
# 555        misratah      LY  32.38   15.09     81.52        58  1595252184
# 556    tandlianwala      PK  31.03   73.13     92.98        53  1595252185
# 558         peniche      PT  39.36   -9.38     88.00        67  1595252188
#
#      Clouds  Wind Speed
# 0         5        9.17
# 1        11        5.26
# 2        75        6.93
# 3        20        6.93
# 4        90        5.82
# ..      ...         ...
# 552      20        4.47
# 553      35        4.00
# 555       0       12.66
# 556      31       21.41
# 558      35        8.01
#
# [366 rows x 9 columns]

# %%
#create filter for southern hemisphere
isSouth = clean_data['Lat'] <= 0
isSouth.value_counts()
# Out:
# False    366
# True     167
# Name: Lat, dtype: int64

# %%
#southern hem dataframe

southern_hem = clean_data.loc[isSouth, :]
southern_hem
# Out:
#                     City Country    Lat     Lon  Max Temp  Humidity  \
# 5                 atuona      PF  -9.80 -139.03     79.50        76
# 6                rikitea      PF -23.12 -134.97     68.32        61
# 7                ushuaia      AR -54.80  -68.30     24.80        85
# 10            luganville      VU -15.53  167.17     69.80        77
# 11               chicama      PE  -7.84  -79.15     62.46        81
# ..                   ...     ...    ...     ...       ...       ...
# 543  santiago del estero      AR -27.80  -64.26     68.09        66
# 545              kirando      TZ  -7.42   30.60     77.99        45
# 547               wanaka      NZ -44.70  169.15     40.48        83
# 550         christchurch      NZ -43.53  172.63     53.60        66
# 554               pangai      TO -19.80 -174.35     73.40        88
#
#            Date  Clouds  Wind Speed
# 5    1595251064      26       15.41
# 6    1595251057      98       13.42
# 7    1595251004      20        4.70
# 10   1595251446      75        3.36
# 11   1595251236      74        3.49
# ..          ...     ...         ...
# 543  1595252169     100       12.44
# 545  1595252171       2        7.23
# 547  1595252174     100        2.51
# 550  1595252162       2       19.46
# 554  1595252183      75        5.82
#
# [167 rows x 9 columns]

# %%
#northern hemisphere max temp vs. latitutde linear regression
x_values = northern_hem['Lat']
y_values = northern_hem['Max Temp']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
regress_values

line_eq = "y = " + str(round(slope,2)) + "x " + str(round(intercept,2))

plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq, (10,50), fontsize=15,color="red")

plt.title('Northern Hemisphere (Max Vs Lat) Linear Regression')
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.grid()

print(f"The r-squared is: {rvalue**2}")

plt.savefig("output_data/nhemMaxLatReg.png")
plt.show()
# Out:
# The r-squared is: 0.4176529277352057

# %%
#southern hemisphere max temp vs. latitutde linear regression

x_values = southern_hem['Lat']
y_values = southern_hem['Max Temp']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
regress_values

line_eq = "y = " + str(round(slope,2)) + "x " + str(round(intercept,2))

plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq, (10,50), fontsize=15,color="red")

plt.title('Southern Hemisphere (Max Vs Lat) Linear Regression')
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.grid()

print(f"The r-squared is: {rvalue**2}")

plt.savefig("output_data/shemMaxLatReg.png")
plt.show()
# Out:
# The r-squared is: 0.6471144605672843

# %%
#northern hemisphere lat vs. humidity
x_values = northern_hem['Lat']
y_values = northern_hem['Humidity']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
regress_values

line_eq = "y = " + str(round(slope,2)) + "x " + str(round(intercept,2))

plt.scatter(x_values, y_values, color="green", alpha=0.5)
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq, (10,6), fontsize=15,color="red")

plt.title('Northern Hemisphere (Humidity Vs Lat) Linear Regression')
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.grid()

print(f"The r-squared is: {rvalue**2}")

plt.savefig("output_data/nhemHumLatReg.png")
plt.show()
# Out:
# The r-squared is: 0.0016213388072841776

# %%
#southern hemisphere lat vs. humidity
x_values = southern_hem['Lat']
y_values = southern_hem['Humidity']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
regress_values

line_eq = "y = " + str(round(slope,2)) + "x " + str(round(intercept,2))

plt.scatter(x_values, y_values, color="green", alpha=0.5)
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq, (10,10), fontsize=15,color="red")

plt.title('Southern Hemisphere (Humidity Vs Lat) Linear Regression')
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.grid()

print(f"The r-squared is: {rvalue**2}")

plt.savefig("output_data/shemHumLatReg.png")
plt.show()
# Out:
# The r-squared is: 7.321621429645586e-05

# %%
#northern hemisphere lat vs. cloudiness
x_values = northern_hem['Lat']
y_values = northern_hem['Clouds']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
regress_values

line_eq = "y = " + str(round(slope,2)) + "x " + str(round(intercept,2))

plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq, (10,6), fontsize=15,color="red")

plt.title('Northern Hemisphere (Cloudiness Vs Lat) Linear Regression')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.grid()

print(f"The r-squared is: {rvalue**2}")

plt.savefig("output_data/nhemCloudLatReg.png")
plt.show()
# Out:
# The r-squared is: 0.0022590219064131073

# %%
#southern hemisphere lat vs. clouds
x_values = southern_hem['Lat']
y_values = southern_hem['Clouds']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
regress_values

line_eq = "y = " + str(round(slope,2)) + "x " + str(round(intercept,2))

plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq, (10,6), fontsize=15,color="red")

plt.title('Southern Hemisphere (Cloudiness Vs Lat) Linear Regression')
plt.xlabel('Latitude')
plt.ylabel('Clouds')
plt.grid()

print(f"The r-squared is: {rvalue**2}")

plt.savefig("output_data/shemCloudLatReg.png")
plt.show()
# Out:
# The r-squared is: 8.916778102336933e-05

# %%
#northern hemisphere wind speed Vs Lat
x_values = northern_hem['Lat']
y_values = northern_hem['Wind Speed']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
regress_values

line_eq = "y = " + str(round(slope,2)) + "x " + str(round(intercept,2))

plt.scatter(x_values, y_values, color="green", alpha=0.5)
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq, (10,30), fontsize=15,color="red")

plt.title('Northern Hemisphere (Wind Speed Vs Lat) Linear Regression')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.grid()

print(f"The r-squared is: {rvalue**2}")

plt.savefig("output_data/nhemWindLatReg.png")
plt.show()
# Out:
# The r-squared is: 0.019030113645190163

# %%
#southern hemisphere lat Vs. wind speed

x_values = southern_hem['Lat']
y_values = southern_hem['Wind Speed']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
regress_values

line_eq = "y = " + str(round(slope,2)) + "x " + str(round(intercept,2))

plt.scatter(x_values, y_values, color="green", alpha=0.5)
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq, (10,10), fontsize=15,color="red")

plt.title('Southern Hemisphere (Wind peed Vs Lat) Linear Regression')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.grid()

print(f"The r-squared is: {rvalue**2}")

plt.savefig("output_data/shemWindLatReg.png")
plt.show()
# Out:
# The r-squared is: 0.009040207191838042
